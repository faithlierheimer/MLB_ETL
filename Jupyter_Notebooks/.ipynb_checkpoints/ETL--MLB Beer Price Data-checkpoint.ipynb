# %% [markdown]
# ## Data Source: Data.world
# [Data.World MLB Beer Cost](https://data.world/makeovermonday/2018w43-what-will-a-beer-cost-you-at-every-major-league-ba)
#
# E: Extract from Data.World

# %%
#Import Dependencies
import pandas as pd
import pymongo as pm
from pymongo import MongoClient

# %% [markdown]
# ### T: Transform into DF, drop anything unnecessary, standardize

# %%
#Import data into a df
beer = pd.read_csv(r'C:\Users\flier\Desktop\MLB_ETL\Raw_Data\mlb_beer_prices.csv')
beer.head()
# Out:
#    Year                  Team      Nickname       City   Price    Size   \
# 0  2013  Arizona Diamondbacks  Diamondbacks    Arizona     4.00      14
# 1  2013        Atlanta Braves        Braves    Atlanta     7.25      16
# 2  2013     Baltimore Orioles       Orioles  Baltimore     6.75      18
# 3  2013        Boston Red Sox       Red Sox     Boston     7.25      12
# 4  2013          Chicago Cubs          Cubs    Chicago     7.25      16
#
#     Price per Ounce
# 0               0.29
# 1               0.45
# 2               0.38
# 3               0.60
# 4               0.45

# %%
##More T--drop team nickname-DON'T RUN TWICE IN ONE SESSION
beer = beer.drop(labels='Nickname', axis=1)
beer
# Out:
#      Year                  Team        City   Price    Size   \
# 0    2013  Arizona Diamondbacks     Arizona     4.00      14
# 1    2013        Atlanta Braves     Atlanta     7.25      16
# 2    2013     Baltimore Orioles   Baltimore     6.75      18
# 3    2013        Boston Red Sox      Boston     7.25      12
# 4    2013          Chicago Cubs     Chicago     7.25      16
# ..    ...                   ...         ...      ...     ...
# 150  2018        Tampa Bay Rays       Tampa     5.00      12
# 151  2018         Texas Rangers   Arlington     6.00      16
# 152  2018     Toronto Blue Jays     Toronto     5.67      14
# 153  2018  Washington Nationals  Washington     7.00      14
# 154  2018           MLB Average         NaN     5.98      14
#
#       Price per Ounce
# 0                 0.29
# 1                 0.45
# 2                 0.38
# 3                 0.60
# 4                 0.45
# ..                 ...
# 150               0.42
# 151               0.38
# 152               0.41
# 153               0.50
# 154               0.43
#
# [155 rows x 6 columns]

# %%
##T-rename columns
beer.columns = ['year', 'team', 'city', 'price', 'size', 'price_per_oz']
beer
# Out:
#      year                  team        city  price  size  price_per_oz
# 0    2013  Arizona Diamondbacks     Arizona   4.00    14          0.29
# 1    2013        Atlanta Braves     Atlanta   7.25    16          0.45
# 2    2013     Baltimore Orioles   Baltimore   6.75    18          0.38
# 3    2013        Boston Red Sox      Boston   7.25    12          0.60
# 4    2013          Chicago Cubs     Chicago   7.25    16          0.45
# ..    ...                   ...         ...    ...   ...           ...
# 150  2018        Tampa Bay Rays       Tampa   5.00    12          0.42
# 151  2018         Texas Rangers   Arlington   6.00    16          0.38
# 152  2018     Toronto Blue Jays     Toronto   5.67    14          0.41
# 153  2018  Washington Nationals  Washington   7.00    14          0.50
# 154  2018           MLB Average         NaN   5.98    14          0.43
#
# [155 rows x 6 columns]

# %%
##T--group by team name for ease of loading into df?
beer_groupby = beer.groupby(["team", "price"], as_index=False).mean()['price']
beer_groupby
# Out:
# 0     4.00
# 1     5.00
# 2     7.25
# 3     7.75
# 4     4.00
#       ...
# 62    6.82
# 63    7.34
# 64    6.50
# 65    7.00
# 66    8.25
# Name: price, Length: 67, dtype: float64

# %%
##Make dictionary version of beer data for mongo?
beer_dict = beer.to_dict('records')
beer_dict
#Put dictionary entries in a list--should be easier to mass insert? 
mongo_beer_docs = []
mongo_beer_docs += [beer_dict]
mongo_beer_docs
# Out:
# [[{'year': 2013,
#    'team': 'Arizona Diamondbacks',
#    'city': 'Arizona',
#    'price': 4.0,
#    'size': 14,
#    'price_per_oz': 0.29},
#   {'year': 2013,
#    'team': 'Atlanta Braves',
#    'city': 'Atlanta',
#    'price': 7.25,
#    'size': 16,
#    'price_per_oz': 0.45},
#   {'year': 2013,
#    'team': 'Baltimore Orioles',
#    'city': 'Baltimore',
#    'price': 6.75,
#    'size': 18,
#    'price_per_oz': 0.38},
#   {'year': 2013,
#    'team': 'Boston Red Sox',
#    'city': 'Boston',
#    'price': 7.25,
#    'size': 12,
#    'price_per_oz': 0.6},
#   {'year': 2013,
#    'team': 'Chicago Cubs',
#    'city': 'Chicago',
#    'price': 7.25,
#    'size': 16,
#    'price_per_oz': 0.45},
#   {'year': 2013,
#    'team': 'Chicago White Sox',
#    'city': 'Chicago',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2013,
#    'team': 'Cincinnati Reds',
#    'city': 'Cincinnati',
#    'price': 5.5,
#    'size': 12,
#    'price_per_oz': 0.46},
#   {'year': 2013,
#    'team': 'Cleveland Indians',
#    'city': 'Cleveland',
#    'price': 4.0,
#    'size': 12,
#    'price_per_oz': 0.33},
#   {'year': 2013,
#    'team': 'Colorado Rockies',
#    'city': 'Colorado',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2013,
#    'team': 'Detroit Tigers',
#    'city': 'Detroit',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2013,
#    'team': 'Houston Astros',
#    'city': 'Houston',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2013,
#    'team': 'Kansas City Royals',
#    'city': 'Kansas City',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2013,
#    'team': 'Los Angeles Angels',
#    'city': 'Anaheim',
#    'price': 4.5,
#    'size': 16,
#    'price_per_oz': 0.28},
#   {'year': 2013,
#    'team': 'Los Angeles Dodgers',
#    'city': 'Los Angeles',
#    'price': 6.25,
#    'size': 16,
#    'price_per_oz': 0.39},
#   {'year': 2013,
#    'team': 'Miami Marlins',
#    'city': 'Miami',
#    'price': 8.0,
#    'size': 20,
#    'price_per_oz': 0.4},
#   {'year': 2013,
#    'team': 'Milwaukee Brewers',
#    'city': 'Milwaukee',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2013,
#    'team': 'Minnesota Twins',
#    'city': 'Minnesota',
#    'price': 7.5,
#    'size': 20,
#    'price_per_oz': 0.38},
#   {'year': 2013,
#    'team': 'New York Mets',
#    'city': 'New York',
#    'price': 5.75,
#    'size': 12,
#    'price_per_oz': 0.48},
#   {'year': 2013,
#    'team': 'New York Yankees',
#    'city': 'New York',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2013,
#    'team': 'Oakland Athletics',
#    'city': 'Oakland',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2013,
#    'team': 'Philadelphia Phillies',
#    'city': 'Philadelphia',
#    'price': 7.75,
#    'size': 21,
#    'price_per_oz': 0.37},
#   {'year': 2013,
#    'team': 'Pittsburgh Pirates',
#    'city': 'Pittsburgh',
#    'price': 5.5,
#    'size': 16,
#    'price_per_oz': 0.34},
#   {'year': 2013,
#    'team': 'San Diego Padres',
#    'city': 'San Diego',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2013,
#    'team': 'San Francisco Giants',
#    'city': 'San Francisco',
#    'price': 6.75,
#    'size': 16,
#    'price_per_oz': 0.42},
#   {'year': 2013,
#    'team': 'Seattle Mariners',
#    'city': 'Seattle',
#    'price': 5.5,
#    'size': 12,
#    'price_per_oz': 0.46},
#   {'year': 2013,
#    'team': 'St. Louis Cardinals',
#    'city': 'St. Louis',
#    'price': 6.75,
#    'size': 12,
#    'price_per_oz': 0.56},
#   {'year': 2013,
#    'team': 'Tampa Bay Rays',
#    'city': 'Tampa',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2013,
#    'team': 'Texas Rangers',
#    'city': 'Arlington',
#    'price': 5.0,
#    'size': 16,
#    'price_per_oz': 0.31},
#   {'year': 2013,
#    'team': 'Toronto Blue Jays',
#    'city': 'Toronto',
#    'price': 7.34,
#    'size': 14,
#    'price_per_oz': 0.52},
#   {'year': 2013,
#    'team': 'Washington Nationals',
#    'city': 'Washington',
#    'price': 8.25,
#    'size': 16,
#    'price_per_oz': 0.52},
#   {'year': 2013,
#    'team': 'MLB Average',
#    'city': nan,
#    'price': 6.09,
#    'size': 15,
#    'price_per_oz': 0.41},
#   {'year': 2014,
#    'team': 'Arizona Diamondbacks',
#    'city': 'Arizona',
#    'price': 4.0,
#    'size': 14,
#    'price_per_oz': 0.29},
#   {'year': 2014,
#    'team': 'Atlanta Braves',
#    'city': 'Atlanta',
#    'price': 7.25,
#    'size': 16,
#    'price_per_oz': 0.45},
#   {'year': 2014,
#    'team': 'Baltimore Orioles',
#    'city': 'Baltimore',
#    'price': 6.75,
#    'size': 16,
#    'price_per_oz': 0.42},
#   {'year': 2014,
#    'team': 'Boston Red Sox',
#    'city': 'Boston',
#    'price': 7.75,
#    'size': 12,
#    'price_per_oz': 0.65},
#   {'year': 2014,
#    'team': 'Chicago Cubs',
#    'city': 'Chicago',
#    'price': 7.5,
#    'size': 16,
#    'price_per_oz': 0.47},
#   {'year': 2014,
#    'team': 'Chicago White Sox',
#    'city': 'Chicago',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2014,
#    'team': 'Cincinnati Reds',
#    'city': 'Cincinnati',
#    'price': 5.5,
#    'size': 12,
#    'price_per_oz': 0.46},
#   {'year': 2014,
#    'team': 'Cleveland Indians',
#    'city': 'Cleveland',
#    'price': 4.0,
#    'size': 12,
#    'price_per_oz': 0.33},
#   {'year': 2014,
#    'team': 'Colorado Rockies',
#    'city': 'Colorado',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2014,
#    'team': 'Detroit Tigers',
#    'city': 'Detroit',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2014,
#    'team': 'Houston Astros',
#    'city': 'Houston',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2014,
#    'team': 'Kansas City Royals',
#    'city': 'Kansas City',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2014,
#    'team': 'Los Angeles Angels',
#    'city': 'Anaheim',
#    'price': 4.5,
#    'size': 16,
#    'price_per_oz': 0.28},
#   {'year': 2014,
#    'team': 'Los Angeles Dodgers',
#    'city': 'Los Angeles',
#    'price': 6.75,
#    'size': 20,
#    'price_per_oz': 0.34},
#   {'year': 2014,
#    'team': 'Miami Marlins',
#    'city': 'Miami',
#    'price': 8.0,
#    'size': 16,
#    'price_per_oz': 0.5},
#   {'year': 2014,
#    'team': 'Milwaukee Brewers',
#    'city': 'Milwaukee',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2014,
#    'team': 'Minnesota Twins',
#    'city': 'Minnesota',
#    'price': 7.5,
#    'size': 20,
#    'price_per_oz': 0.38},
#   {'year': 2014,
#    'team': 'New York Mets',
#    'city': 'New York',
#    'price': 5.75,
#    'size': 12,
#    'price_per_oz': 0.48},
#   {'year': 2014,
#    'team': 'New York Yankees',
#    'city': 'New York',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2014,
#    'team': 'Oakland Athletics',
#    'city': 'Oakland',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2014,
#    'team': 'Philadelphia Phillies',
#    'city': 'Philadelphia',
#    'price': 7.75,
#    'size': 21,
#    'price_per_oz': 0.37},
#   {'year': 2014,
#    'team': 'Pittsburgh Pirates',
#    'city': 'Pittsburgh',
#    'price': 5.5,
#    'size': 16,
#    'price_per_oz': 0.34},
#   {'year': 2014,
#    'team': 'San Diego Padres',
#    'city': 'San Diego',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2014,
#    'team': 'San Francisco Giants',
#    'city': 'San Francisco',
#    'price': 7.0,
#    'size': 14,
#    'price_per_oz': 0.5},
#   {'year': 2014,
#    'team': 'Seattle Mariners',
#    'city': 'Seattle',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2014,
#    'team': 'St. Louis Cardinals',
#    'city': 'St. Louis',
#    'price': 6.75,
#    'size': 12,
#    'price_per_oz': 0.56},
#   {'year': 2014,
#    'team': 'Tampa Bay Rays',
#    'city': 'Tampa',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2014,
#    'team': 'Texas Rangers',
#    'city': 'Arlington',
#    'price': 5.0,
#    'size': 16,
#    'price_per_oz': 0.31},
#   {'year': 2014,
#    'team': 'Toronto Blue Jays',
#    'city': 'Toronto',
#    'price': 6.82,
#    'size': 14,
#    'price_per_oz': 0.49},
#   {'year': 2014,
#    'team': 'Washington Nationals',
#    'city': 'Washington',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2014,
#    'team': 'MLB Average',
#    'city': nan,
#    'price': 6.09,
#    'size': 15,
#    'price_per_oz': 0.41},
#   {'year': 2015,
#    'team': 'Arizona Diamondbacks',
#    'city': 'Arizona',
#    'price': 4.0,
#    'size': 14,
#    'price_per_oz': 0.29},
#   {'year': 2015,
#    'team': 'Atlanta Braves',
#    'city': 'Atlanta',
#    'price': 7.25,
#    'size': 16,
#    'price_per_oz': 0.45},
#   {'year': 2015,
#    'team': 'Baltimore Orioles',
#    'city': 'Baltimore',
#    'price': 6.75,
#    'size': 16,
#    'price_per_oz': 0.42},
#   {'year': 2015,
#    'team': 'Boston Red Sox',
#    'city': 'Boston',
#    'price': 7.75,
#    'size': 12,
#    'price_per_oz': 0.65},
#   {'year': 2015,
#    'team': 'Chicago Cubs',
#    'city': 'Chicago',
#    'price': 7.5,
#    'size': 16,
#    'price_per_oz': 0.47},
#   {'year': 2015,
#    'team': 'Chicago White Sox',
#    'city': 'Chicago',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2015,
#    'team': 'Cincinnati Reds',
#    'city': 'Cincinnati',
#    'price': 5.5,
#    'size': 12,
#    'price_per_oz': 0.46},
#   {'year': 2015,
#    'team': 'Cleveland Indians',
#    'city': 'Cleveland',
#    'price': 4.0,
#    'size': 12,
#    'price_per_oz': 0.33},
#   {'year': 2015,
#    'team': 'Colorado Rockies',
#    'city': 'Colorado',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2015,
#    'team': 'Detroit Tigers',
#    'city': 'Detroit',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2015,
#    'team': 'Houston Astros',
#    'city': 'Houston',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2015,
#    'team': 'Kansas City Royals',
#    'city': 'Kansas City',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2015,
#    'team': 'Los Angeles Angels',
#    'city': 'Anaheim',
#    'price': 4.5,
#    'size': 16,
#    'price_per_oz': 0.28},
#   {'year': 2015,
#    'team': 'Los Angeles Dodgers',
#    'city': 'Los Angeles',
#    'price': 6.75,
#    'size': 20,
#    'price_per_oz': 0.34},
#   {'year': 2015,
#    'team': 'Miami Marlins',
#    'city': 'Miami',
#    'price': 8.0,
#    'size': 16,
#    'price_per_oz': 0.5},
#   {'year': 2015,
#    'team': 'Milwaukee Brewers',
#    'city': 'Milwaukee',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2015,
#    'team': 'Minnesota Twins',
#    'city': 'Minnesota',
#    'price': 7.5,
#    'size': 20,
#    'price_per_oz': 0.38},
#   {'year': 2015,
#    'team': 'New York Mets',
#    'city': 'New York',
#    'price': 5.75,
#    'size': 12,
#    'price_per_oz': 0.48},
#   {'year': 2015,
#    'team': 'New York Yankees',
#    'city': 'New York',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2015,
#    'team': 'Oakland Athletics',
#    'city': 'Oakland',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2015,
#    'team': 'Philadelphia Phillies',
#    'city': 'Philadelphia',
#    'price': 7.75,
#    'size': 21,
#    'price_per_oz': 0.37},
#   {'year': 2015,
#    'team': 'Pittsburgh Pirates',
#    'city': 'Pittsburgh',
#    'price': 5.5,
#    'size': 16,
#    'price_per_oz': 0.34},
#   {'year': 2015,
#    'team': 'San Diego Padres',
#    'city': 'San Diego',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2015,
#    'team': 'San Francisco Giants',
#    'city': 'San Francisco',
#    'price': 7.0,
#    'size': 14,
#    'price_per_oz': 0.5},
#   {'year': 2015,
#    'team': 'Seattle Mariners',
#    'city': 'Seattle',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2015,
#    'team': 'St. Louis Cardinals',
#    'city': 'St. Louis',
#    'price': 6.75,
#    'size': 12,
#    'price_per_oz': 0.56},
#   {'year': 2015,
#    'team': 'Tampa Bay Rays',
#    'city': 'Tampa',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2015,
#    'team': 'Texas Rangers',
#    'city': 'Arlington',
#    'price': 5.0,
#    'size': 16,
#    'price_per_oz': 0.31},
#   {'year': 2015,
#    'team': 'Toronto Blue Jays',
#    'city': 'Toronto',
#    'price': 6.82,
#    'size': 14,
#    'price_per_oz': 0.49},
#   {'year': 2015,
#    'team': 'Washington Nationals',
#    'city': 'Washington',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2015,
#    'team': 'MLB Average',
#    'city': nan,
#    'price': 5.98,
#    'size': 15,
#    'price_per_oz': 0.4},
#   {'year': 2016,
#    'team': 'Arizona Diamondbacks',
#    'city': 'Arizona',
#    'price': 4.0,
#    'size': 14,
#    'price_per_oz': 0.29},
#   {'year': 2016,
#    'team': 'Atlanta Braves',
#    'city': 'Atlanta',
#    'price': 7.75,
#    'size': 16,
#    'price_per_oz': 0.48},
#   {'year': 2016,
#    'team': 'Baltimore Orioles',
#    'city': 'Baltimore',
#    'price': 6.75,
#    'size': 16,
#    'price_per_oz': 0.42},
#   {'year': 2016,
#    'team': 'Boston Red Sox',
#    'city': 'Boston',
#    'price': 7.75,
#    'size': 12,
#    'price_per_oz': 0.65},
#   {'year': 2016,
#    'team': 'Chicago Cubs',
#    'city': 'Chicago',
#    'price': 7.5,
#    'size': 16,
#    'price_per_oz': 0.47},
#   {'year': 2016,
#    'team': 'Chicago White Sox',
#    'city': 'Chicago',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2016,
#    'team': 'Cincinnati Reds',
#    'city': 'Cincinnati',
#    'price': 5.25,
#    'size': 14,
#    'price_per_oz': 0.38},
#   {'year': 2016,
#    'team': 'Cleveland Indians',
#    'city': 'Cleveland',
#    'price': 4.0,
#    'size': 12,
#    'price_per_oz': 0.33},
#   {'year': 2016,
#    'team': 'Colorado Rockies',
#    'city': 'Colorado',
#    'price': 3.0,
#    'size': 12,
#    'price_per_oz': 0.25},
#   {'year': 2016,
#    'team': 'Detroit Tigers',
#    'city': 'Detroit',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2016,
#    'team': 'Houston Astros',
#    'city': 'Houston',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2016,
#    'team': 'Kansas City Royals',
#    'city': 'Kansas City',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2016,
#    'team': 'Los Angeles Angels',
#    'city': 'Anaheim',
#    'price': 4.5,
#    'size': 16,
#    'price_per_oz': 0.28},
#   {'year': 2016,
#    'team': 'Los Angeles Dodgers',
#    'city': 'Los Angeles',
#    'price': 6.25,
#    'size': 20,
#    'price_per_oz': 0.31},
#   {'year': 2016,
#    'team': 'Miami Marlins',
#    'city': 'Miami',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2016,
#    'team': 'Milwaukee Brewers',
#    'city': 'Milwaukee',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2016,
#    'team': 'Minnesota Twins',
#    'city': 'Minnesota',
#    'price': 7.5,
#    'size': 20,
#    'price_per_oz': 0.38},
#   {'year': 2016,
#    'team': 'New York Mets',
#    'city': 'New York',
#    'price': 5.75,
#    'size': 12,
#    'price_per_oz': 0.48},
#   {'year': 2016,
#    'team': 'New York Yankees',
#    'city': 'New York',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2016,
#    'team': 'Oakland Athletics',
#    'city': 'Oakland',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2016,
#    'team': 'Philadelphia Phillies',
#    'city': 'Philadelphia',
#    'price': 7.75,
#    'size': 21,
#    'price_per_oz': 0.37},
#   {'year': 2016,
#    'team': 'Pittsburgh Pirates',
#    'city': 'Pittsburgh',
#    'price': 5.5,
#    'size': 16,
#    'price_per_oz': 0.34},
#   {'year': 2016,
#    'team': 'San Diego Padres',
#    'city': 'San Diego',
#    'price': 5.0,
#    'size': 14,
#    'price_per_oz': 0.36},
#   {'year': 2016,
#    'team': 'San Francisco Giants',
#    'city': 'San Francisco',
#    'price': 7.5,
#    'size': 14,
#    'price_per_oz': 0.54},
#   {'year': 2016,
#    'team': 'Seattle Mariners',
#    'city': 'Seattle',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2016,
#    'team': 'St. Louis Cardinals',
#    'city': 'St. Louis',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2016,
#    'team': 'Tampa Bay Rays',
#    'city': 'Tampa',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2016,
#    'team': 'Texas Rangers',
#    'city': 'Arlington',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2016,
#    'team': 'Toronto Blue Jays',
#    'city': 'Toronto',
#    'price': 6.79,
#    'size': 14,
#    'price_per_oz': 0.49},
#   {'year': 2016,
#    'team': 'Washington Nationals',
#    'city': 'Washington',
#    'price': 6.5,
#    'size': 16,
#    'price_per_oz': 0.41},
#   {'year': 2016,
#    'team': 'MLB Average',
#    'city': nan,
#    'price': 5.9,
#    'size': 15,
#    'price_per_oz': 0.4},
#   {'year': 2018,
#    'team': 'Arizona Diamondbacks',
#    'city': 'Arizona',
#    'price': 4.0,
#    'size': 14,
#    'price_per_oz': 0.29},
#   {'year': 2018,
#    'team': 'Atlanta Braves',
#    'city': 'Atlanta',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'Baltimore Orioles',
#    'city': 'Baltimore',
#    'price': 4.0,
#    'size': 12,
#    'price_per_oz': 0.33},
#   {'year': 2018,
#    'team': 'Boston Red Sox',
#    'city': 'Boston',
#    'price': 8.0,
#    'size': 12,
#    'price_per_oz': 0.67},
#   {'year': 2018,
#    'team': 'Chicago Cubs',
#    'city': 'Chicago',
#    'price': 9.0,
#    'size': 20,
#    'price_per_oz': 0.45},
#   {'year': 2018,
#    'team': 'Chicago White Sox',
#    'city': 'Chicago',
#    'price': 7.0,
#    'size': 16,
#    'price_per_oz': 0.44},
#   {'year': 2018,
#    'team': 'Cincinnati Reds',
#    'city': 'Cincinnati',
#    'price': 6.25,
#    'size': 14,
#    'price_per_oz': 0.45},
#   {'year': 2018,
#    'team': 'Cleveland Indians',
#    'city': 'Cleveland',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'Colorado Rockies',
#    'city': 'Colorado',
#    'price': 3.0,
#    'size': 12,
#    'price_per_oz': 0.25},
#   {'year': 2018,
#    'team': 'Detroit Tigers',
#    'city': 'Detroit',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'Houston Astros',
#    'city': 'Houston',
#    'price': 6.0,
#    'size': 14,
#    'price_per_oz': 0.43},
#   {'year': 2018,
#    'team': 'Kansas City Royals',
#    'city': 'Kansas City',
#    'price': 4.0,
#    'size': 12,
#    'price_per_oz': 0.33},
#   {'year': 2018,
#    'team': 'Los Angeles Angels',
#    'city': 'Anaheim',
#    'price': 4.5,
#    'size': 12,
#    'price_per_oz': 0.38},
#   {'year': 2018,
#    'team': 'Los Angeles Dodgers',
#    'city': 'Los Angeles',
#    'price': 6.25,
#    'size': 16,
#    'price_per_oz': 0.39},
#   {'year': 2018,
#    'team': 'Miami Marlins',
#    'city': 'Miami',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2018,
#    'team': 'Milwaukee Brewers',
#    'city': 'Milwaukee',
#    'price': 7.0,
#    'size': 16,
#    'price_per_oz': 0.44},
#   {'year': 2018,
#    'team': 'Minnesota Twins',
#    'city': 'Minnesota',
#    'price': 8.5,
#    'size': 20,
#    'price_per_oz': 0.43},
#   {'year': 2018,
#    'team': 'New York Mets',
#    'city': 'New York',
#    'price': 10.5,
#    'size': 20,
#    'price_per_oz': 0.53},
#   {'year': 2018,
#    'team': 'New York Yankees',
#    'city': 'New York',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2018,
#    'team': 'Oakland Athletics',
#    'city': 'Oakland',
#    'price': 5.5,
#    'size': 12,
#    'price_per_oz': 0.46},
#   {'year': 2018,
#    'team': 'Philadelphia Phillies',
#    'city': 'Philadelphia',
#    'price': 6.0,
#    'size': 12,
#    'price_per_oz': 0.5},
#   {'year': 2018,
#    'team': 'Pittsburgh Pirates',
#    'city': 'Pittsburgh',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2018,
#    'team': 'San Diego Padres',
#    'city': 'San Diego',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'San Francisco Giants',
#    'city': 'San Francisco',
#    'price': 8.25,
#    'size': 14,
#    'price_per_oz': 0.59},
#   {'year': 2018,
#    'team': 'Seattle Mariners',
#    'city': 'Seattle',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'St. Louis Cardinals',
#    'city': 'St. Louis',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'Tampa Bay Rays',
#    'city': 'Tampa',
#    'price': 5.0,
#    'size': 12,
#    'price_per_oz': 0.42},
#   {'year': 2018,
#    'team': 'Texas Rangers',
#    'city': 'Arlington',
#    'price': 6.0,
#    'size': 16,
#    'price_per_oz': 0.38},
#   {'year': 2018,
#    'team': 'Toronto Blue Jays',
#    'city': 'Toronto',
#    'price': 5.67,
#    'size': 14,
#    'price_per_oz': 0.41},
#   {'year': 2018,
#    'team': 'Washington Nationals',
#    'city': 'Washington',
#    'price': 7.0,
#    'size': 14,
#    'price_per_oz': 0.5},
#   {'year': 2018,
#    'team': 'MLB Average',
#    'city': nan,
#    'price': 5.98,
#    'size': 14,
#    'price_per_oz': 0.43}]]

# %%
##L-load into mongo db--commented out for now
## cluster = MongoClient("PUT CONNECTION STRING HERE")
## db = cluster['NAME OF MLB DATABASE']
## collection = db['PUT COLLECTION NAME HERE FOR BEER']
## collection.insert_many(beer_dict)

# %%
#Export edited beer prices data
beer.to_csv('../mlb_beer_cleaned.csv')
