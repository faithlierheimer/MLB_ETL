# %% [markdown]
# ## Trying to set up mongo DB to put two datasets into their own collections

# %%
##Dependencies
import pandas as pd
import pymongo 
from pymongo import MongoClient

# %%
##Import beer data
beer_csv = pd.read_csv("..\cleaned_data\mlb_beer_cleaned.csv")
beer_csv.head()
# Out:
#    Unnamed: 0  year                  team       city  price  size  \
# 0           0  2013  Arizona Diamondbacks    Arizona   4.00    14
# 1           1  2013        Atlanta Braves    Atlanta   7.25    16
# 2           2  2013     Baltimore Orioles  Baltimore   6.75    18
# 3           3  2013        Boston Red Sox     Boston   7.25    12
# 4           4  2013          Chicago Cubs    Chicago   7.25    16
#
#    price_per_oz
# 0          0.29
# 1          0.45
# 2          0.38
# 3          0.60
# 4          0.45

# %%
##Convert beer data to dict
beer_dict = beer_csv.to_dict('records')
beer_dict[0]
# Out:
# {'Unnamed: 0': 0,
#  'year': 2013,
#  'team': 'Arizona Diamondbacks',
#  'city': 'Arizona',
#  'price': 4.0,
#  'size': 14,
#  'price_per_oz': 0.29}

# %%
##Set up client
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.mlb

# %%
##Insert beer dictionary into "beer" collection
db.beer.insert_many(beer_dict)

# %%
#Delete test doc
db.beer.delete_one({'test':'beer'})

# %%
#Confirm deletion of test doc
beer = db.beer.find()
for i in beer:
    print(i)
# Out:
# {'_id': ObjectId('5f57b3596da87065af1b3c42'), 'Unnamed: 0': 0, 'year': 2013, 'team': 'Arizona Diamondbacks', 'city': 'Arizona', 'price': 4.0, 'size': 14, 'price_per_oz': 0.29}
# {'_id': ObjectId('5f57b3596da87065af1b3c43'), 'Unnamed: 0': 1, 'year': 2013, 'team': 'Atlanta Braves', 'city': 'Atlanta', 'price': 7.25, 'size': 16, 'price_per_oz': 0.45}
# {'_id': ObjectId('5f57b3596da87065af1b3c44'), 'Unnamed: 0': 2, 'year': 2013, 'team': 'Baltimore Orioles', 'city': 'Baltimore', 'price': 6.75, 'size': 18, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c45'), 'Unnamed: 0': 3, 'year': 2013, 'team': 'Boston Red Sox', 'city': 'Boston', 'price': 7.25, 'size': 12, 'price_per_oz': 0.6}
# {'_id': ObjectId('5f57b3596da87065af1b3c46'), 'Unnamed: 0': 4, 'year': 2013, 'team': 'Chicago Cubs', 'city': 'Chicago', 'price': 7.25, 'size': 16, 'price_per_oz': 0.45}
# {'_id': ObjectId('5f57b3596da87065af1b3c47'), 'Unnamed: 0': 5, 'year': 2013, 'team': 'Chicago White Sox', 'city': 'Chicago', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c48'), 'Unnamed: 0': 6, 'year': 2013, 'team': 'Cincinnati Reds', 'city': 'Cincinnati', 'price': 5.5, 'size': 12, 'price_per_oz': 0.46}
# {'_id': ObjectId('5f57b3596da87065af1b3c49'), 'Unnamed: 0': 7, 'year': 2013, 'team': 'Cleveland Indians', 'city': 'Cleveland', 'price': 4.0, 'size': 12, 'price_per_oz': 0.33}
# {'_id': ObjectId('5f57b3596da87065af1b3c4a'), 'Unnamed: 0': 8, 'year': 2013, 'team': 'Colorado Rockies', 'city': 'Colorado', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c4b'), 'Unnamed: 0': 9, 'year': 2013, 'team': 'Detroit Tigers', 'city': 'Detroit', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c4c'), 'Unnamed: 0': 10, 'year': 2013, 'team': 'Houston Astros', 'city': 'Houston', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c4d'), 'Unnamed: 0': 11, 'year': 2013, 'team': 'Kansas City Royals', 'city': 'Kansas City', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c4e'), 'Unnamed: 0': 12, 'year': 2013, 'team': 'Los Angeles Angels', 'city': 'Anaheim', 'price': 4.5, 'size': 16, 'price_per_oz': 0.28}
# {'_id': ObjectId('5f57b3596da87065af1b3c4f'), 'Unnamed: 0': 13, 'year': 2013, 'team': 'Los Angeles Dodgers', 'city': 'Los Angeles', 'price': 6.25, 'size': 16, 'price_per_oz': 0.39}
# {'_id': ObjectId('5f57b3596da87065af1b3c50'), 'Unnamed: 0': 14, 'year': 2013, 'team': 'Miami Marlins', 'city': 'Miami', 'price': 8.0, 'size': 20, 'price_per_oz': 0.4}
# {'_id': ObjectId('5f57b3596da87065af1b3c51'), 'Unnamed: 0': 15, 'year': 2013, 'team': 'Milwaukee Brewers', 'city': 'Milwaukee', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c52'), 'Unnamed: 0': 16, 'year': 2013, 'team': 'Minnesota Twins', 'city': 'Minnesota', 'price': 7.5, 'size': 20, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c53'), 'Unnamed: 0': 17, 'year': 2013, 'team': 'New York Mets', 'city': 'New York', 'price': 5.75, 'size': 12, 'price_per_oz': 0.48}
# {'_id': ObjectId('5f57b3596da87065af1b3c54'), 'Unnamed: 0': 18, 'year': 2013, 'team': 'New York Yankees', 'city': 'New York', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c55'), 'Unnamed: 0': 19, 'year': 2013, 'team': 'Oakland Athletics', 'city': 'Oakland', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c56'), 'Unnamed: 0': 20, 'year': 2013, 'team': 'Philadelphia Phillies', 'city': 'Philadelphia', 'price': 7.75, 'size': 21, 'price_per_oz': 0.37}
# {'_id': ObjectId('5f57b3596da87065af1b3c57'), 'Unnamed: 0': 21, 'year': 2013, 'team': 'Pittsburgh Pirates', 'city': 'Pittsburgh', 'price': 5.5, 'size': 16, 'price_per_oz': 0.34}
# {'_id': ObjectId('5f57b3596da87065af1b3c58'), 'Unnamed: 0': 22, 'year': 2013, 'team': 'San Diego Padres', 'city': 'San Diego', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c59'), 'Unnamed: 0': 23, 'year': 2013, 'team': 'San Francisco Giants', 'city': 'San Francisco', 'price': 6.75, 'size': 16, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c5a'), 'Unnamed: 0': 24, 'year': 2013, 'team': 'Seattle Mariners', 'city': 'Seattle', 'price': 5.5, 'size': 12, 'price_per_oz': 0.46}
# {'_id': ObjectId('5f57b3596da87065af1b3c5b'), 'Unnamed: 0': 25, 'year': 2013, 'team': 'St. Louis Cardinals', 'city': 'St. Louis', 'price': 6.75, 'size': 12, 'price_per_oz': 0.56}
# {'_id': ObjectId('5f57b3596da87065af1b3c5c'), 'Unnamed: 0': 26, 'year': 2013, 'team': 'Tampa Bay Rays', 'city': 'Tampa', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c5d'), 'Unnamed: 0': 27, 'year': 2013, 'team': 'Texas Rangers', 'city': 'Arlington', 'price': 5.0, 'size': 16, 'price_per_oz': 0.31}
# {'_id': ObjectId('5f57b3596da87065af1b3c5e'), 'Unnamed: 0': 28, 'year': 2013, 'team': 'Toronto Blue Jays', 'city': 'Toronto', 'price': 7.34, 'size': 14, 'price_per_oz': 0.52}
# {'_id': ObjectId('5f57b3596da87065af1b3c5f'), 'Unnamed: 0': 29, 'year': 2013, 'team': 'Washington Nationals', 'city': 'Washington', 'price': 8.25, 'size': 16, 'price_per_oz': 0.52}
# {'_id': ObjectId('5f57b3596da87065af1b3c60'), 'Unnamed: 0': 30, 'year': 2013, 'team': 'MLB Average', 'city': nan, 'price': 6.09, 'size': 15, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c61'), 'Unnamed: 0': 31, 'year': 2014, 'team': 'Arizona Diamondbacks', 'city': 'Arizona', 'price': 4.0, 'size': 14, 'price_per_oz': 0.29}
# {'_id': ObjectId('5f57b3596da87065af1b3c62'), 'Unnamed: 0': 32, 'year': 2014, 'team': 'Atlanta Braves', 'city': 'Atlanta', 'price': 7.25, 'size': 16, 'price_per_oz': 0.45}
# {'_id': ObjectId('5f57b3596da87065af1b3c63'), 'Unnamed: 0': 33, 'year': 2014, 'team': 'Baltimore Orioles', 'city': 'Baltimore', 'price': 6.75, 'size': 16, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c64'), 'Unnamed: 0': 34, 'year': 2014, 'team': 'Boston Red Sox', 'city': 'Boston', 'price': 7.75, 'size': 12, 'price_per_oz': 0.65}
# {'_id': ObjectId('5f57b3596da87065af1b3c65'), 'Unnamed: 0': 35, 'year': 2014, 'team': 'Chicago Cubs', 'city': 'Chicago', 'price': 7.5, 'size': 16, 'price_per_oz': 0.47}
# {'_id': ObjectId('5f57b3596da87065af1b3c66'), 'Unnamed: 0': 36, 'year': 2014, 'team': 'Chicago White Sox', 'city': 'Chicago', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c67'), 'Unnamed: 0': 37, 'year': 2014, 'team': 'Cincinnati Reds', 'city': 'Cincinnati', 'price': 5.5, 'size': 12, 'price_per_oz': 0.46}
# {'_id': ObjectId('5f57b3596da87065af1b3c68'), 'Unnamed: 0': 38, 'year': 2014, 'team': 'Cleveland Indians', 'city': 'Cleveland', 'price': 4.0, 'size': 12, 'price_per_oz': 0.33}
# {'_id': ObjectId('5f57b3596da87065af1b3c69'), 'Unnamed: 0': 39, 'year': 2014, 'team': 'Colorado Rockies', 'city': 'Colorado', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c6a'), 'Unnamed: 0': 40, 'year': 2014, 'team': 'Detroit Tigers', 'city': 'Detroit', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c6b'), 'Unnamed: 0': 41, 'year': 2014, 'team': 'Houston Astros', 'city': 'Houston', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c6c'), 'Unnamed: 0': 42, 'year': 2014, 'team': 'Kansas City Royals', 'city': 'Kansas City', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c6d'), 'Unnamed: 0': 43, 'year': 2014, 'team': 'Los Angeles Angels', 'city': 'Anaheim', 'price': 4.5, 'size': 16, 'price_per_oz': 0.28}
# {'_id': ObjectId('5f57b3596da87065af1b3c6e'), 'Unnamed: 0': 44, 'year': 2014, 'team': 'Los Angeles Dodgers', 'city': 'Los Angeles', 'price': 6.75, 'size': 20, 'price_per_oz': 0.34}
# {'_id': ObjectId('5f57b3596da87065af1b3c6f'), 'Unnamed: 0': 45, 'year': 2014, 'team': 'Miami Marlins', 'city': 'Miami', 'price': 8.0, 'size': 16, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c70'), 'Unnamed: 0': 46, 'year': 2014, 'team': 'Milwaukee Brewers', 'city': 'Milwaukee', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c71'), 'Unnamed: 0': 47, 'year': 2014, 'team': 'Minnesota Twins', 'city': 'Minnesota', 'price': 7.5, 'size': 20, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c72'), 'Unnamed: 0': 48, 'year': 2014, 'team': 'New York Mets', 'city': 'New York', 'price': 5.75, 'size': 12, 'price_per_oz': 0.48}
# {'_id': ObjectId('5f57b3596da87065af1b3c73'), 'Unnamed: 0': 49, 'year': 2014, 'team': 'New York Yankees', 'city': 'New York', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c74'), 'Unnamed: 0': 50, 'year': 2014, 'team': 'Oakland Athletics', 'city': 'Oakland', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c75'), 'Unnamed: 0': 51, 'year': 2014, 'team': 'Philadelphia Phillies', 'city': 'Philadelphia', 'price': 7.75, 'size': 21, 'price_per_oz': 0.37}
# {'_id': ObjectId('5f57b3596da87065af1b3c76'), 'Unnamed: 0': 52, 'year': 2014, 'team': 'Pittsburgh Pirates', 'city': 'Pittsburgh', 'price': 5.5, 'size': 16, 'price_per_oz': 0.34}
# {'_id': ObjectId('5f57b3596da87065af1b3c77'), 'Unnamed: 0': 53, 'year': 2014, 'team': 'San Diego Padres', 'city': 'San Diego', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c78'), 'Unnamed: 0': 54, 'year': 2014, 'team': 'San Francisco Giants', 'city': 'San Francisco', 'price': 7.0, 'size': 14, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c79'), 'Unnamed: 0': 55, 'year': 2014, 'team': 'Seattle Mariners', 'city': 'Seattle', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c7a'), 'Unnamed: 0': 56, 'year': 2014, 'team': 'St. Louis Cardinals', 'city': 'St. Louis', 'price': 6.75, 'size': 12, 'price_per_oz': 0.56}
# {'_id': ObjectId('5f57b3596da87065af1b3c7b'), 'Unnamed: 0': 57, 'year': 2014, 'team': 'Tampa Bay Rays', 'city': 'Tampa', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c7c'), 'Unnamed: 0': 58, 'year': 2014, 'team': 'Texas Rangers', 'city': 'Arlington', 'price': 5.0, 'size': 16, 'price_per_oz': 0.31}
# {'_id': ObjectId('5f57b3596da87065af1b3c7d'), 'Unnamed: 0': 59, 'year': 2014, 'team': 'Toronto Blue Jays', 'city': 'Toronto', 'price': 6.82, 'size': 14, 'price_per_oz': 0.49}
# {'_id': ObjectId('5f57b3596da87065af1b3c7e'), 'Unnamed: 0': 60, 'year': 2014, 'team': 'Washington Nationals', 'city': 'Washington', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c7f'), 'Unnamed: 0': 61, 'year': 2014, 'team': 'MLB Average', 'city': nan, 'price': 6.09, 'size': 15, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c80'), 'Unnamed: 0': 62, 'year': 2015, 'team': 'Arizona Diamondbacks', 'city': 'Arizona', 'price': 4.0, 'size': 14, 'price_per_oz': 0.29}
# {'_id': ObjectId('5f57b3596da87065af1b3c81'), 'Unnamed: 0': 63, 'year': 2015, 'team': 'Atlanta Braves', 'city': 'Atlanta', 'price': 7.25, 'size': 16, 'price_per_oz': 0.45}
# {'_id': ObjectId('5f57b3596da87065af1b3c82'), 'Unnamed: 0': 64, 'year': 2015, 'team': 'Baltimore Orioles', 'city': 'Baltimore', 'price': 6.75, 'size': 16, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c83'), 'Unnamed: 0': 65, 'year': 2015, 'team': 'Boston Red Sox', 'city': 'Boston', 'price': 7.75, 'size': 12, 'price_per_oz': 0.65}
# {'_id': ObjectId('5f57b3596da87065af1b3c84'), 'Unnamed: 0': 66, 'year': 2015, 'team': 'Chicago Cubs', 'city': 'Chicago', 'price': 7.5, 'size': 16, 'price_per_oz': 0.47}
# {'_id': ObjectId('5f57b3596da87065af1b3c85'), 'Unnamed: 0': 67, 'year': 2015, 'team': 'Chicago White Sox', 'city': 'Chicago', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c86'), 'Unnamed: 0': 68, 'year': 2015, 'team': 'Cincinnati Reds', 'city': 'Cincinnati', 'price': 5.5, 'size': 12, 'price_per_oz': 0.46}
# {'_id': ObjectId('5f57b3596da87065af1b3c87'), 'Unnamed: 0': 69, 'year': 2015, 'team': 'Cleveland Indians', 'city': 'Cleveland', 'price': 4.0, 'size': 12, 'price_per_oz': 0.33}
# {'_id': ObjectId('5f57b3596da87065af1b3c88'), 'Unnamed: 0': 70, 'year': 2015, 'team': 'Colorado Rockies', 'city': 'Colorado', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c89'), 'Unnamed: 0': 71, 'year': 2015, 'team': 'Detroit Tigers', 'city': 'Detroit', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c8a'), 'Unnamed: 0': 72, 'year': 2015, 'team': 'Houston Astros', 'city': 'Houston', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c8b'), 'Unnamed: 0': 73, 'year': 2015, 'team': 'Kansas City Royals', 'city': 'Kansas City', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c8c'), 'Unnamed: 0': 74, 'year': 2015, 'team': 'Los Angeles Angels', 'city': 'Anaheim', 'price': 4.5, 'size': 16, 'price_per_oz': 0.28}
# {'_id': ObjectId('5f57b3596da87065af1b3c8d'), 'Unnamed: 0': 75, 'year': 2015, 'team': 'Los Angeles Dodgers', 'city': 'Los Angeles', 'price': 6.75, 'size': 20, 'price_per_oz': 0.34}
# {'_id': ObjectId('5f57b3596da87065af1b3c8e'), 'Unnamed: 0': 76, 'year': 2015, 'team': 'Miami Marlins', 'city': 'Miami', 'price': 8.0, 'size': 16, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c8f'), 'Unnamed: 0': 77, 'year': 2015, 'team': 'Milwaukee Brewers', 'city': 'Milwaukee', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c90'), 'Unnamed: 0': 78, 'year': 2015, 'team': 'Minnesota Twins', 'city': 'Minnesota', 'price': 7.5, 'size': 20, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3c91'), 'Unnamed: 0': 79, 'year': 2015, 'team': 'New York Mets', 'city': 'New York', 'price': 5.75, 'size': 12, 'price_per_oz': 0.48}
# {'_id': ObjectId('5f57b3596da87065af1b3c92'), 'Unnamed: 0': 80, 'year': 2015, 'team': 'New York Yankees', 'city': 'New York', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c93'), 'Unnamed: 0': 81, 'year': 2015, 'team': 'Oakland Athletics', 'city': 'Oakland', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c94'), 'Unnamed: 0': 82, 'year': 2015, 'team': 'Philadelphia Phillies', 'city': 'Philadelphia', 'price': 7.75, 'size': 21, 'price_per_oz': 0.37}
# {'_id': ObjectId('5f57b3596da87065af1b3c95'), 'Unnamed: 0': 83, 'year': 2015, 'team': 'Pittsburgh Pirates', 'city': 'Pittsburgh', 'price': 5.5, 'size': 16, 'price_per_oz': 0.34}
# {'_id': ObjectId('5f57b3596da87065af1b3c96'), 'Unnamed: 0': 84, 'year': 2015, 'team': 'San Diego Padres', 'city': 'San Diego', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3c97'), 'Unnamed: 0': 85, 'year': 2015, 'team': 'San Francisco Giants', 'city': 'San Francisco', 'price': 7.0, 'size': 14, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c98'), 'Unnamed: 0': 86, 'year': 2015, 'team': 'Seattle Mariners', 'city': 'Seattle', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3c99'), 'Unnamed: 0': 87, 'year': 2015, 'team': 'St. Louis Cardinals', 'city': 'St. Louis', 'price': 6.75, 'size': 12, 'price_per_oz': 0.56}
# {'_id': ObjectId('5f57b3596da87065af1b3c9a'), 'Unnamed: 0': 88, 'year': 2015, 'team': 'Tampa Bay Rays', 'city': 'Tampa', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3c9b'), 'Unnamed: 0': 89, 'year': 2015, 'team': 'Texas Rangers', 'city': 'Arlington', 'price': 5.0, 'size': 16, 'price_per_oz': 0.31}
# {'_id': ObjectId('5f57b3596da87065af1b3c9c'), 'Unnamed: 0': 90, 'year': 2015, 'team': 'Toronto Blue Jays', 'city': 'Toronto', 'price': 6.82, 'size': 14, 'price_per_oz': 0.49}
# {'_id': ObjectId('5f57b3596da87065af1b3c9d'), 'Unnamed: 0': 91, 'year': 2015, 'team': 'Washington Nationals', 'city': 'Washington', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3c9e'), 'Unnamed: 0': 92, 'year': 2015, 'team': 'MLB Average', 'city': nan, 'price': 5.98, 'size': 15, 'price_per_oz': 0.4}
# {'_id': ObjectId('5f57b3596da87065af1b3c9f'), 'Unnamed: 0': 93, 'year': 2016, 'team': 'Arizona Diamondbacks', 'city': 'Arizona', 'price': 4.0, 'size': 14, 'price_per_oz': 0.29}
# {'_id': ObjectId('5f57b3596da87065af1b3ca0'), 'Unnamed: 0': 94, 'year': 2016, 'team': 'Atlanta Braves', 'city': 'Atlanta', 'price': 7.75, 'size': 16, 'price_per_oz': 0.48}
# {'_id': ObjectId('5f57b3596da87065af1b3ca1'), 'Unnamed: 0': 95, 'year': 2016, 'team': 'Baltimore Orioles', 'city': 'Baltimore', 'price': 6.75, 'size': 16, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3ca2'), 'Unnamed: 0': 96, 'year': 2016, 'team': 'Boston Red Sox', 'city': 'Boston', 'price': 7.75, 'size': 12, 'price_per_oz': 0.65}
# {'_id': ObjectId('5f57b3596da87065af1b3ca3'), 'Unnamed: 0': 97, 'year': 2016, 'team': 'Chicago Cubs', 'city': 'Chicago', 'price': 7.5, 'size': 16, 'price_per_oz': 0.47}
# {'_id': ObjectId('5f57b3596da87065af1b3ca4'), 'Unnamed: 0': 98, 'year': 2016, 'team': 'Chicago White Sox', 'city': 'Chicago', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3ca5'), 'Unnamed: 0': 99, 'year': 2016, 'team': 'Cincinnati Reds', 'city': 'Cincinnati', 'price': 5.25, 'size': 14, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3ca6'), 'Unnamed: 0': 100, 'year': 2016, 'team': 'Cleveland Indians', 'city': 'Cleveland', 'price': 4.0, 'size': 12, 'price_per_oz': 0.33}
# {'_id': ObjectId('5f57b3596da87065af1b3ca7'), 'Unnamed: 0': 101, 'year': 2016, 'team': 'Colorado Rockies', 'city': 'Colorado', 'price': 3.0, 'size': 12, 'price_per_oz': 0.25}
# {'_id': ObjectId('5f57b3596da87065af1b3ca8'), 'Unnamed: 0': 102, 'year': 2016, 'team': 'Detroit Tigers', 'city': 'Detroit', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3ca9'), 'Unnamed: 0': 103, 'year': 2016, 'team': 'Houston Astros', 'city': 'Houston', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3caa'), 'Unnamed: 0': 104, 'year': 2016, 'team': 'Kansas City Royals', 'city': 'Kansas City', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3cab'), 'Unnamed: 0': 105, 'year': 2016, 'team': 'Los Angeles Angels', 'city': 'Anaheim', 'price': 4.5, 'size': 16, 'price_per_oz': 0.28}
# {'_id': ObjectId('5f57b3596da87065af1b3cac'), 'Unnamed: 0': 106, 'year': 2016, 'team': 'Los Angeles Dodgers', 'city': 'Los Angeles', 'price': 6.25, 'size': 20, 'price_per_oz': 0.31}
# {'_id': ObjectId('5f57b3596da87065af1b3cad'), 'Unnamed: 0': 107, 'year': 2016, 'team': 'Miami Marlins', 'city': 'Miami', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3cae'), 'Unnamed: 0': 108, 'year': 2016, 'team': 'Milwaukee Brewers', 'city': 'Milwaukee', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3caf'), 'Unnamed: 0': 109, 'year': 2016, 'team': 'Minnesota Twins', 'city': 'Minnesota', 'price': 7.5, 'size': 20, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3cb0'), 'Unnamed: 0': 110, 'year': 2016, 'team': 'New York Mets', 'city': 'New York', 'price': 5.75, 'size': 12, 'price_per_oz': 0.48}
# {'_id': ObjectId('5f57b3596da87065af1b3cb1'), 'Unnamed: 0': 111, 'year': 2016, 'team': 'New York Yankees', 'city': 'New York', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3cb2'), 'Unnamed: 0': 112, 'year': 2016, 'team': 'Oakland Athletics', 'city': 'Oakland', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cb3'), 'Unnamed: 0': 113, 'year': 2016, 'team': 'Philadelphia Phillies', 'city': 'Philadelphia', 'price': 7.75, 'size': 21, 'price_per_oz': 0.37}
# {'_id': ObjectId('5f57b3596da87065af1b3cb4'), 'Unnamed: 0': 114, 'year': 2016, 'team': 'Pittsburgh Pirates', 'city': 'Pittsburgh', 'price': 5.5, 'size': 16, 'price_per_oz': 0.34}
# {'_id': ObjectId('5f57b3596da87065af1b3cb5'), 'Unnamed: 0': 115, 'year': 2016, 'team': 'San Diego Padres', 'city': 'San Diego', 'price': 5.0, 'size': 14, 'price_per_oz': 0.36}
# {'_id': ObjectId('5f57b3596da87065af1b3cb6'), 'Unnamed: 0': 116, 'year': 2016, 'team': 'San Francisco Giants', 'city': 'San Francisco', 'price': 7.5, 'size': 14, 'price_per_oz': 0.54}
# {'_id': ObjectId('5f57b3596da87065af1b3cb7'), 'Unnamed: 0': 117, 'year': 2016, 'team': 'Seattle Mariners', 'city': 'Seattle', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3cb8'), 'Unnamed: 0': 118, 'year': 2016, 'team': 'St. Louis Cardinals', 'city': 'St. Louis', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cb9'), 'Unnamed: 0': 119, 'year': 2016, 'team': 'Tampa Bay Rays', 'city': 'Tampa', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cba'), 'Unnamed: 0': 120, 'year': 2016, 'team': 'Texas Rangers', 'city': 'Arlington', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3cbb'), 'Unnamed: 0': 121, 'year': 2016, 'team': 'Toronto Blue Jays', 'city': 'Toronto', 'price': 6.79, 'size': 14, 'price_per_oz': 0.49}
# {'_id': ObjectId('5f57b3596da87065af1b3cbc'), 'Unnamed: 0': 122, 'year': 2016, 'team': 'Washington Nationals', 'city': 'Washington', 'price': 6.5, 'size': 16, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3cbd'), 'Unnamed: 0': 123, 'year': 2016, 'team': 'MLB Average', 'city': nan, 'price': 5.9, 'size': 15, 'price_per_oz': 0.4}
# {'_id': ObjectId('5f57b3596da87065af1b3cbe'), 'Unnamed: 0': 124, 'year': 2018, 'team': 'Arizona Diamondbacks', 'city': 'Arizona', 'price': 4.0, 'size': 14, 'price_per_oz': 0.29}
# {'_id': ObjectId('5f57b3596da87065af1b3cbf'), 'Unnamed: 0': 125, 'year': 2018, 'team': 'Atlanta Braves', 'city': 'Atlanta', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cc0'), 'Unnamed: 0': 126, 'year': 2018, 'team': 'Baltimore Orioles', 'city': 'Baltimore', 'price': 4.0, 'size': 12, 'price_per_oz': 0.33}
# {'_id': ObjectId('5f57b3596da87065af1b3cc1'), 'Unnamed: 0': 127, 'year': 2018, 'team': 'Boston Red Sox', 'city': 'Boston', 'price': 8.0, 'size': 12, 'price_per_oz': 0.67}
# {'_id': ObjectId('5f57b3596da87065af1b3cc2'), 'Unnamed: 0': 128, 'year': 2018, 'team': 'Chicago Cubs', 'city': 'Chicago', 'price': 9.0, 'size': 20, 'price_per_oz': 0.45}
# {'_id': ObjectId('5f57b3596da87065af1b3cc3'), 'Unnamed: 0': 129, 'year': 2018, 'team': 'Chicago White Sox', 'city': 'Chicago', 'price': 7.0, 'size': 16, 'price_per_oz': 0.44}
# {'_id': ObjectId('5f57b3596da87065af1b3cc4'), 'Unnamed: 0': 130, 'year': 2018, 'team': 'Cincinnati Reds', 'city': 'Cincinnati', 'price': 6.25, 'size': 14, 'price_per_oz': 0.45}
# {'_id': ObjectId('5f57b3596da87065af1b3cc5'), 'Unnamed: 0': 131, 'year': 2018, 'team': 'Cleveland Indians', 'city': 'Cleveland', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cc6'), 'Unnamed: 0': 132, 'year': 2018, 'team': 'Colorado Rockies', 'city': 'Colorado', 'price': 3.0, 'size': 12, 'price_per_oz': 0.25}
# {'_id': ObjectId('5f57b3596da87065af1b3cc7'), 'Unnamed: 0': 133, 'year': 2018, 'team': 'Detroit Tigers', 'city': 'Detroit', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cc8'), 'Unnamed: 0': 134, 'year': 2018, 'team': 'Houston Astros', 'city': 'Houston', 'price': 6.0, 'size': 14, 'price_per_oz': 0.43}
# {'_id': ObjectId('5f57b3596da87065af1b3cc9'), 'Unnamed: 0': 135, 'year': 2018, 'team': 'Kansas City Royals', 'city': 'Kansas City', 'price': 4.0, 'size': 12, 'price_per_oz': 0.33}
# {'_id': ObjectId('5f57b3596da87065af1b3cca'), 'Unnamed: 0': 136, 'year': 2018, 'team': 'Los Angeles Angels', 'city': 'Anaheim', 'price': 4.5, 'size': 12, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3ccb'), 'Unnamed: 0': 137, 'year': 2018, 'team': 'Los Angeles Dodgers', 'city': 'Los Angeles', 'price': 6.25, 'size': 16, 'price_per_oz': 0.39}
# {'_id': ObjectId('5f57b3596da87065af1b3ccc'), 'Unnamed: 0': 138, 'year': 2018, 'team': 'Miami Marlins', 'city': 'Miami', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3ccd'), 'Unnamed: 0': 139, 'year': 2018, 'team': 'Milwaukee Brewers', 'city': 'Milwaukee', 'price': 7.0, 'size': 16, 'price_per_oz': 0.44}
# {'_id': ObjectId('5f57b3596da87065af1b3cce'), 'Unnamed: 0': 140, 'year': 2018, 'team': 'Minnesota Twins', 'city': 'Minnesota', 'price': 8.5, 'size': 20, 'price_per_oz': 0.43}
# {'_id': ObjectId('5f57b3596da87065af1b3ccf'), 'Unnamed: 0': 141, 'year': 2018, 'team': 'New York Mets', 'city': 'New York', 'price': 10.5, 'size': 20, 'price_per_oz': 0.53}
# {'_id': ObjectId('5f57b3596da87065af1b3cd0'), 'Unnamed: 0': 142, 'year': 2018, 'team': 'New York Yankees', 'city': 'New York', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3cd1'), 'Unnamed: 0': 143, 'year': 2018, 'team': 'Oakland Athletics', 'city': 'Oakland', 'price': 5.5, 'size': 12, 'price_per_oz': 0.46}
# {'_id': ObjectId('5f57b3596da87065af1b3cd2'), 'Unnamed: 0': 144, 'year': 2018, 'team': 'Philadelphia Phillies', 'city': 'Philadelphia', 'price': 6.0, 'size': 12, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3cd3'), 'Unnamed: 0': 145, 'year': 2018, 'team': 'Pittsburgh Pirates', 'city': 'Pittsburgh', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3cd4'), 'Unnamed: 0': 146, 'year': 2018, 'team': 'San Diego Padres', 'city': 'San Diego', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cd5'), 'Unnamed: 0': 147, 'year': 2018, 'team': 'San Francisco Giants', 'city': 'San Francisco', 'price': 8.25, 'size': 14, 'price_per_oz': 0.59}
# {'_id': ObjectId('5f57b3596da87065af1b3cd6'), 'Unnamed: 0': 148, 'year': 2018, 'team': 'Seattle Mariners', 'city': 'Seattle', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cd7'), 'Unnamed: 0': 149, 'year': 2018, 'team': 'St. Louis Cardinals', 'city': 'St. Louis', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cd8'), 'Unnamed: 0': 150, 'year': 2018, 'team': 'Tampa Bay Rays', 'city': 'Tampa', 'price': 5.0, 'size': 12, 'price_per_oz': 0.42}
# {'_id': ObjectId('5f57b3596da87065af1b3cd9'), 'Unnamed: 0': 151, 'year': 2018, 'team': 'Texas Rangers', 'city': 'Arlington', 'price': 6.0, 'size': 16, 'price_per_oz': 0.38}
# {'_id': ObjectId('5f57b3596da87065af1b3cda'), 'Unnamed: 0': 152, 'year': 2018, 'team': 'Toronto Blue Jays', 'city': 'Toronto', 'price': 5.67, 'size': 14, 'price_per_oz': 0.41}
# {'_id': ObjectId('5f57b3596da87065af1b3cdb'), 'Unnamed: 0': 153, 'year': 2018, 'team': 'Washington Nationals', 'city': 'Washington', 'price': 7.0, 'size': 14, 'price_per_oz': 0.5}
# {'_id': ObjectId('5f57b3596da87065af1b3cdc'), 'Unnamed: 0': 154, 'year': 2018, 'team': 'MLB Average', 'city': nan, 'price': 5.98, 'size': 14, 'price_per_oz': 0.43}

# %%
##Bring in player stats doc so it fits w/beer but in a separate collection
api_stats = pd.read_csv("..\cleaned_data\stats.csv")
api_stats.head()
# Out:
#    Player ID first_name last_name               team   hits   avg  homeruns  \
# 0     547989       Jose     Abreu  Chicago White Sox  132.0  .265      22.0
# 1     660670     Ronald     Acuna     Atlanta Braves  127.0  .293      26.0
# 2     592094      Jason      Adam       Chicago Cubs    0.0  .---       0.0
# 3     642715      Willy    Adames     Tampa Bay Rays   80.0  .278      10.0
# 4     613534     Austin     Adams   San Diego Padres    0.0  .---       0.0
#
#    atbats   obp  stolenbases   rbi
# 0   499.0  .325          2.0  78.0
# 1   433.0  .366         16.0  64.0
# 2     0.0  .---          0.0   0.0
# 3   288.0  .348          6.0  34.0
# 4     0.0  .---          0.0   0.0

# %%
#Fill NAs with 0s
api_stats = api_stats.fillna(value = 0 )
api_stats.head()
# Out:
#    Player ID first_name last_name               team   hits   avg  homeruns  \
# 0     547989       Jose     Abreu  Chicago White Sox  132.0  .265      22.0
# 1     660670     Ronald     Acuna     Atlanta Braves  127.0  .293      26.0
# 2     592094      Jason      Adam       Chicago Cubs    0.0  .---       0.0
# 3     642715      Willy    Adames     Tampa Bay Rays   80.0  .278      10.0
# 4     613534     Austin     Adams   San Diego Padres    0.0  .---       0.0
#
#    atbats   obp  stolenbases   rbi
# 0   499.0  .325          2.0  78.0
# 1   433.0  .366         16.0  64.0
# 2     0.0  .---          0.0   0.0
# 3   288.0  .348          6.0  34.0
# 4     0.0  .---          0.0   0.0

# %%
api_stats.isnull().sum()
# Out:
# Player ID      0
# first_name     0
# last_name      0
# team           0
# hits           0
# avg            0
# homeruns       0
# atbats         0
# obp            0
# stolenbases    0
# rbi            0
# dtype: int64

# %%
##Convert api data to dict
api_dict = api_stats.to_dict('records')
api_dict[0]
# Out:
# {'Player ID': 547989,
#  'first_name': 'Jose',
#  'last_name': 'Abreu',
#  'team': 'Chicago White Sox',
#  'hits': 132.0,
#  'avg': '.265',
#  'homeruns': 22.0,
#  'atbats': 499.0,
#  'obp': '.325',
#  'stolenbases': 2.0,
#  'rbi': 78.0}

# %%
##Insert api dictionary into "api_stats" collection
db.api_stats.insert_many(api_dict)

# %%
#Confirm insertion of API data into api_stats db
api = db.api_stats.find()
for i in api:
    print(i)
# Out:
# {'_id': ObjectId('5f57b84a6da87065af1b3cde'), 'Player ID': 547989, 'first_name': 'Jose', 'last_name': 'Abreu', 'team': 'Chicago White Sox', 'hits': 132.0, 'avg': '.265', 'homeruns': 22.0, 'atbats': 499.0, 'obp': '.325', 'stolenbases': 2.0, 'rbi': 78.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cdf'), 'Player ID': 660670, 'first_name': 'Ronald', 'last_name': 'Acuna', 'team': 'Atlanta Braves', 'hits': 127.0, 'avg': '.293', 'homeruns': 26.0, 'atbats': 433.0, 'obp': '.366', 'stolenbases': 16.0, 'rbi': 64.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce0'), 'Player ID': 592094, 'first_name': 'Jason', 'last_name': 'Adam', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce1'), 'Player ID': 642715, 'first_name': 'Willy', 'last_name': 'Adames', 'team': 'Tampa Bay Rays', 'hits': 80.0, 'avg': '.278', 'homeruns': 10.0, 'atbats': 288.0, 'obp': '.348', 'stolenbases': 6.0, 'rbi': 34.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce2'), 'Player ID': 613534, 'first_name': 'Austin', 'last_name': 'Adams', 'team': 'San Diego Padres', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce3'), 'Player ID': 664856, 'first_name': 'Chance', 'last_name': 'Adams', 'team': 'Kansas City Royals', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce4'), 'Player ID': 572669, 'first_name': 'Lane', 'last_name': 'Adams', 'team': 'Minnesota Twins', 'hits': 6.0, 'avg': '.240', 'homeruns': 2.0, 'atbats': 25.0, 'obp': '.345', 'stolenbases': 1.0, 'rbi': 6.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce5'), 'Player ID': 571431, 'first_name': 'Matt', 'last_name': 'Adams', 'team': 'Atlanta Braves', 'hits': 73.0, 'avg': '.239', 'homeruns': 21.0, 'atbats': 306.0, 'obp': '.309', 'stolenbases': 0.0, 'rbi': 57.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce6'), 'Player ID': 451192, 'first_name': 'Jim', 'last_name': 'Adduci', 'team': 'Nashville Sounds', 'hits': 47.0, 'avg': '.267', 'homeruns': 3.0, 'atbats': 176.0, 'obp': '.290', 'stolenbases': 1.0, 'rbi': 21.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce7'), 'Player ID': 501303, 'first_name': 'Ehire', 'last_name': 'Adrianza', 'team': 'Minnesota Twins', 'hits': 84.0, 'avg': '.251', 'homeruns': 6.0, 'atbats': 335.0, 'obp': '.301', 'stolenbases': 5.0, 'rbi': 39.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce8'), 'Player ID': 542583, 'first_name': 'Jesus', 'last_name': 'Aguilar', 'team': 'Miami Marlins', 'hits': 135.0, 'avg': '.274', 'homeruns': 35.0, 'atbats': 492.0, 'obp': '.352', 'stolenbases': 0.0, 'rbi': 108.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ce9'), 'Player ID': 605113, 'first_name': 'Nick', 'last_name': 'Ahmed', 'team': 'Arizona Diamondbacks', 'hits': 121.0, 'avg': '.234', 'homeruns': 16.0, 'atbats': 516.0, 'obp': '.290', 'stolenbases': 5.0, 'rbi': 70.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cea'), 'Player ID': 458006, 'first_name': 'Matt', 'last_name': 'Albers', 'team': 'Milwaukee Brewers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ceb'), 'Player ID': 593643, 'first_name': 'Hanser', 'last_name': 'Alberto', 'team': 'Baltimore Orioles', 'hits': 5.0, 'avg': '.185', 'homeruns': 0.0, 'atbats': 27.0, 'obp': '.241', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cec'), 'Player ID': 645277, 'first_name': 'Ozzie', 'last_name': 'Albies', 'team': 'Atlanta Braves', 'hits': 167.0, 'avg': '.261', 'homeruns': 24.0, 'atbats': 639.0, 'obp': '.305', 'stolenbases': 14.0, 'rbi': 72.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3ced'), 'Player ID': 645261, 'first_name': 'Sandy', 'last_name': 'Alcantara', 'team': 'Miami Marlins', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 12.0, 'obp': '.077', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cee'), 'Player ID': 622505, 'first_name': 'Victor', 'last_name': 'Alcantara', 'team': 'Detroit Tigers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cef'), 'Player ID': 518397, 'first_name': 'Scott', 'last_name': 'Alexander', 'team': 'Los Angeles Dodgers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 5.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf0'), 'Player ID': 595751, 'first_name': 'Jorge', 'last_name': 'Alfaro', 'team': 'Miami Marlins', 'hits': 90.0, 'avg': '.262', 'homeruns': 10.0, 'atbats': 344.0, 'obp': '.324', 'stolenbases': 3.0, 'rbi': 37.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf1'), 'Player ID': 546990, 'first_name': 'Anthony', 'last_name': 'Alford', 'team': 'Pittsburgh Pirates', 'hits': 2.0, 'avg': '.105', 'homeruns': 0.0, 'atbats': 19.0, 'obp': '.190', 'stolenbases': 1.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf2'), 'Player ID': 663465, 'first_name': 'Kolby', 'last_name': 'Allard', 'team': 'Texas Rangers', 'hits': 1.0, 'avg': '1.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '1.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf3'), 'Player ID': 592102, 'first_name': 'Cody', 'last_name': 'Allen', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf4'), 'Player ID': 656185, 'first_name': 'Greg', 'last_name': 'Allen', 'team': 'San Diego Padres', 'hits': 68.0, 'avg': '.257', 'homeruns': 2.0, 'atbats': 265.0, 'obp': '.310', 'stolenbases': 21.0, 'rbi': 20.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf5'), 'Player ID': 501659, 'first_name': 'Abraham', 'last_name': 'Almonte', 'team': 'San Diego Padres', 'hits': 24.0, 'avg': '.179', 'homeruns': 3.0, 'atbats': 134.0, 'obp': '.260', 'stolenbases': 2.0, 'rbi': 9.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf6'), 'Player ID': 602083, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf7'), 'Player ID': 622075, 'first_name': 'Yency', 'last_name': 'Almonte', 'team': 'Colorado Rockies', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf8'), 'Player ID': 546991, 'first_name': 'Albert', 'last_name': 'Almora', 'team': 'Chicago Cubs', 'hits': 127.0, 'avg': '.286', 'homeruns': 5.0, 'atbats': 444.0, 'obp': '.323', 'stolenbases': 1.0, 'rbi': 41.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cf9'), 'Player ID': 475174, 'first_name': 'Yonder', 'last_name': 'Alonso', 'team': 'San Diego Padres', 'hits': 129.0, 'avg': '.250', 'homeruns': 23.0, 'atbats': 516.0, 'obp': '.317', 'stolenbases': 0.0, 'rbi': 83.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cfa'), 'Player ID': 656186, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cfb'), 'Player ID': 571437, 'first_name': 'Aaron', 'last_name': 'Altherr', 'team': 'New York Mets', 'hits': 44.0, 'avg': '.181', 'homeruns': 8.0, 'atbats': 243.0, 'obp': '.295', 'stolenbases': 3.0, 'rbi': 38.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cfc'), 'Player ID': 514888, 'first_name': 'Jose', 'last_name': 'Altuve', 'team': 'Houston Astros', 'hits': 169.0, 'avg': '.316', 'homeruns': 13.0, 'atbats': 534.0, 'obp': '.386', 'stolenbases': 17.0, 'rbi': 61.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cfd'), 'Player ID': 621237, 'first_name': 'Jose', 'last_name': 'Alvarado', 'team': 'Tampa Bay Rays', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cfe'), 'Player ID': 501625, 'first_name': 'Jose', 'last_name': 'Alvarez', 'team': 'Philadelphia Phillies', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3cff'), 'Player ID': 476883, 'first_name': 'Pedro', 'last_name': 'Alvarez', 'team': 'New Orleans Baby Cakes', 'hits': 20.0, 'avg': '.180', 'homeruns': 8.0, 'atbats': 111.0, 'obp': '.283', 'stolenbases': 0.0, 'rbi': 18.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d00'), 'Player ID': 474463, 'first_name': 'Brett', 'last_name': 'Anderson', 'team': 'Milwaukee Brewers', 'hits': 1.0, 'avg': '.250', 'homeruns': 0.0, 'atbats': 4.0, 'obp': '.250', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d01'), 'Player ID': 605119, 'first_name': 'Brian', 'last_name': 'Anderson', 'team': 'Miami Marlins', 'hits': 161.0, 'avg': '.273', 'homeruns': 11.0, 'atbats': 590.0, 'obp': '.357', 'stolenbases': 2.0, 'rbi': 65.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d02'), 'Player ID': 502624, 'first_name': 'Chase', 'last_name': 'Anderson', 'team': 'Toronto Blue Jays', 'hits': 4.0, 'avg': '.089', 'homeruns': 0.0, 'atbats': 45.0, 'obp': '.089', 'stolenbases': 0.0, 'rbi': 2.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d03'), 'Player ID': 623454, 'first_name': 'Drew', 'last_name': 'Anderson', 'team': 'Chicago White Sox', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 3.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d04'), 'Player ID': 605121, 'first_name': 'Justin', 'last_name': 'Anderson', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d05'), 'Player ID': 664196, 'first_name': 'Tanner', 'last_name': 'Anderson', 'team': 'Oakland Athletics', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d06'), 'Player ID': 641313, 'first_name': 'Tim', 'last_name': 'Anderson', 'team': 'Chicago White Sox', 'hits': 136.0, 'avg': '.240', 'homeruns': 20.0, 'atbats': 567.0, 'obp': '.281', 'stolenbases': 26.0, 'rbi': 64.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d07'), 'Player ID': 542881, 'first_name': 'Tyler', 'last_name': 'Anderson', 'team': 'San Francisco Giants', 'hits': 5.0, 'avg': '.100', 'homeruns': 0.0, 'atbats': 50.0, 'obp': '.167', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d08'), 'Player ID': 607430, 'first_name': 'John', 'last_name': 'Andreoli', 'team': 'Boston Red Sox', 'hits': 14.0, 'avg': '.230', 'homeruns': 0.0, 'atbats': 61.0, 'obp': '.284', 'stolenbases': 2.0, 'rbi': 4.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d09'), 'Player ID': 542882, 'first_name': 'Matt', 'last_name': 'Andriese', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d0a'), 'Player ID': 462101, 'first_name': 'Elvis', 'last_name': 'Andrus', 'team': 'Texas Rangers', 'hits': 101.0, 'avg': '.256', 'homeruns': 6.0, 'atbats': 395.0, 'obp': '.308', 'stolenbases': 5.0, 'rbi': 33.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d0b'), 'Player ID': 609280, 'first_name': 'Miguel', 'last_name': 'Andujar', 'team': 'New York Yankees', 'hits': 170.0, 'avg': '.297', 'homeruns': 27.0, 'atbats': 573.0, 'obp': '.328', 'stolenbases': 2.0, 'rbi': 92.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d0c'), 'Player ID': 606157, 'first_name': 'Aristides', 'last_name': 'Aquino', 'team': 'Cincinnati Reds', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d0d'), 'Player ID': 644364, 'first_name': 'Victor', 'last_name': 'Arano', 'team': 'Philadelphia Phillies', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d0e'), 'Player ID': 606478, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d0f'), 'Player ID': 502042, 'first_name': 'Chris', 'last_name': 'Archer', 'team': 'Pittsburgh Pirates', 'hits': 2.0, 'avg': '.118', 'homeruns': 0.0, 'atbats': 17.0, 'obp': '.118', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d10'), 'Player ID': 516472, 'first_name': 'Francisco', 'last_name': 'Arcia', 'team': 'Los Angeles Angels', 'hits': 21.0, 'avg': '.204', 'homeruns': 6.0, 'atbats': 103.0, 'obp': '.226', 'stolenbases': 1.0, 'rbi': 23.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d11'), 'Player ID': 606115, 'first_name': 'Orlando', 'last_name': 'Arcia', 'team': 'Milwaukee Brewers', 'hits': 82.0, 'avg': '.236', 'homeruns': 3.0, 'atbats': 348.0, 'obp': '.268', 'stolenbases': 7.0, 'rbi': 30.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d12'), 'Player ID': 571448, 'first_name': 'Nolan', 'last_name': 'Arenado', 'team': 'Colorado Rockies', 'hits': 175.0, 'avg': '.297', 'homeruns': 38.0, 'atbats': 590.0, 'obp': '.374', 'stolenbases': 2.0, 'rbi': 110.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d13'), 'Player ID': 542888, 'first_name': 'Shawn', 'last_name': 'Armstrong', 'team': 'Baltimore Orioles', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d14'), 'Player ID': 453562, 'first_name': 'Jake', 'last_name': 'Arrieta', 'team': 'Philadelphia Phillies', 'hits': 6.0, 'avg': '.133', 'homeruns': 1.0, 'atbats': 45.0, 'obp': '.188', 'stolenbases': 0.0, 'rbi': 3.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d15'), 'Player ID': 624414, 'first_name': 'Christian', 'last_name': 'Arroyo', 'team': 'Boston Red Sox', 'hits': 14.0, 'avg': '.264', 'homeruns': 1.0, 'atbats': 53.0, 'obp': '.339', 'stolenbases': 0.0, 'rbi': 6.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d16'), 'Player ID': 594742, 'first_name': 'Alec', 'last_name': 'Asher', 'team': 'Rochester Red Wings', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d17'), 'Player ID': 553902, 'first_name': 'Willians', 'last_name': 'Astudillo', 'team': 'Minnesota Twins', 'hits': 33.0, 'avg': '.355', 'homeruns': 3.0, 'atbats': 93.0, 'obp': '.371', 'stolenbases': 0.0, 'rbi': 21.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d18'), 'Player ID': 641319, 'first_name': 'Carlos', 'last_name': 'Asuaje', 'team': 'Iowa Cubs', 'hits': 37.0, 'avg': '.196', 'homeruns': 2.0, 'atbats': 189.0, 'obp': '.286', 'stolenbases': 1.0, 'rbi': 19.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d19'), 'Player ID': 592122, 'first_name': 'Tyler', 'last_name': 'Austin', 'team': 'Milwaukee Brewers', 'hits': 56.0, 'avg': '.230', 'homeruns': 17.0, 'atbats': 244.0, 'obp': '.287', 'stolenbases': 1.0, 'rbi': 47.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d1a'), 'Player ID': 623214, 'first_name': 'Abiatal', 'last_name': 'Avelino', 'team': 'San Francisco Giants', 'hits': 3.0, 'avg': '.273', 'homeruns': 0.0, 'atbats': 11.0, 'obp': '.273', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d1b'), 'Player ID': 488671, 'first_name': 'Alex', 'last_name': 'Avila', 'team': 'Minnesota Twins', 'hits': 32.0, 'avg': '.165', 'homeruns': 7.0, 'atbats': 194.0, 'obp': '.299', 'stolenbases': 0.0, 'rbi': 20.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d1c'), 'Player ID': 501593, 'first_name': 'Luis', 'last_name': 'Avilan', 'team': 'New York Yankees', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d1d'), 'Player ID': 446099, 'first_name': 'John', 'last_name': 'Axford', 'team': 'Toronto Blue Jays', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d1e'), 'Player ID': 664056, 'first_name': 'Harrison', 'last_name': 'Bader', 'team': 'St. Louis Cardinals', 'hits': 100.0, 'avg': '.264', 'homeruns': 12.0, 'atbats': 379.0, 'obp': '.334', 'stolenbases': 15.0, 'rbi': 37.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d1f'), 'Player ID': 595879, 'first_name': 'Javier', 'last_name': 'Baez', 'team': 'Chicago Cubs', 'hits': 176.0, 'avg': '.290', 'homeruns': 34.0, 'atbats': 606.0, 'obp': '.326', 'stolenbases': 21.0, 'rbi': 111.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d20'), 'Player ID': 520980, 'first_name': 'Pedro', 'last_name': 'Baez', 'team': 'Los Angeles Dodgers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 4.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d21'), 'Player ID': 622783, 'first_name': 'Sandy', 'last_name': 'Baez', 'team': 'Detroit Tigers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d22'), 'Player ID': 456701, 'first_name': 'Homer', 'last_name': 'Bailey', 'team': 'Minnesota Twins', 'hits': 3.0, 'avg': '.115', 'homeruns': 0.0, 'atbats': 26.0, 'obp': '.148', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d23'), 'Player ID': 607455, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d24'), 'Player ID': 542908, 'first_name': 'Jett', 'last_name': 'Bandy', 'team': 'Boston Red Sox', 'hits': 12.0, 'avg': '.188', 'homeruns': 1.0, 'atbats': 64.0, 'obp': '.268', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d25'), 'Player ID': 592127, 'first_name': 'Johnny', 'last_name': 'Barbato', 'team': 'Detroit Tigers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d26'), 'Player ID': 572703, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d27'), 'Player ID': 605130, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d28'), 'Player ID': 605131, 'first_name': 'Austin', 'last_name': 'Barnes', 'team': 'Los Angeles Dodgers', 'hits': 41.0, 'avg': '.205', 'homeruns': 4.0, 'atbats': 200.0, 'obp': '.329', 'stolenbases': 4.0, 'rbi': 14.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d29'), 'Player ID': 488681, 'first_name': 'Brandon', 'last_name': 'Barnes', 'team': 'Chattanooga Lookouts', 'hits': 5.0, 'avg': '.263', 'homeruns': 1.0, 'atbats': 19.0, 'obp': '.333', 'stolenbases': 0.0, 'rbi': 2.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d2a'), 'Player ID': 592130, 'first_name': 'Danny', 'last_name': 'Barnes', 'team': 'Aberdeen IronBirds', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d2b'), 'Player ID': 606930, 'first_name': 'Jacob', 'last_name': 'Barnes', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d2c'), 'Player ID': 598264, 'first_name': 'Matt', 'last_name': 'Barnes', 'team': 'Boston Red Sox', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d2d'), 'Player ID': 501817, 'first_name': 'Tony', 'last_name': 'Barnette', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d2e'), 'Player ID': 571466, 'first_name': 'Tucker', 'last_name': 'Barnhart', 'team': 'Cincinnati Reds', 'hits': 114.0, 'avg': '.248', 'homeruns': 10.0, 'atbats': 460.0, 'obp': '.328', 'stolenbases': 0.0, 'rbi': 46.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d2f'), 'Player ID': 571467, 'first_name': 'Steven', 'last_name': 'Baron', 'team': 'Cleveland Indians', 'hits': 1.0, 'avg': '.200', 'homeruns': 0.0, 'atbats': 5.0, 'obp': '.200', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d30'), 'Player ID': 607457, 'first_name': 'Kyle', 'last_name': 'Barraclough', 'team': 'El Paso Chihuahuas', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d31'), 'Player ID': 620439, 'first_name': 'Franklin', 'last_name': 'Barreto', 'team': 'Los Angeles Angels', 'hits': 17.0, 'avg': '.233', 'homeruns': 5.0, 'atbats': 73.0, 'obp': '.253', 'stolenbases': 0.0, 'rbi': 16.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d32'), 'Player ID': 545332, 'first_name': 'Jake', 'last_name': 'Barrett', 'team': 'Acereros del Norte', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d33'), 'Player ID': 642545, 'first_name': 'Jaime', 'last_name': 'Barria', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 5.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d34'), 'Player ID': 641341, 'first_name': 'Tyler', 'last_name': 'Bashlor', 'team': 'Pittsburgh Pirates', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d35'), 'Player ID': 542914, 'first_name': 'Anthony', 'last_name': 'Bass', 'team': 'Toronto Blue Jays', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d36'), 'Player ID': 605135, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d37'), 'Player ID': 545333, 'first_name': 'Trevor', 'last_name': 'Bauer', 'team': 'Cincinnati Reds', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 3.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d38'), 'Player ID': 641343, 'first_name': 'Jake', 'last_name': 'Bauers', 'team': 'Cleveland Indians', 'hits': 65.0, 'avg': '.201', 'homeruns': 11.0, 'atbats': 323.0, 'obp': '.316', 'stolenbases': 6.0, 'rbi': 48.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d39'), 'Player ID': 571473, 'first_name': 'Buddy', 'last_name': 'Baumann', 'team': 'New York Mets', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d3a'), 'Player ID': 639373, 'first_name': 'Gerson', 'last_name': 'Bautista', 'team': 'Seattle Mariners', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d3b'), 'Player ID': 430832, 'first_name': 'Jose', 'last_name': 'Bautista', 'team': 'Philadelphia Phillies', 'hits': 66.0, 'avg': '.203', 'homeruns': 13.0, 'atbats': 325.0, 'obp': '.348', 'stolenbases': 4.0, 'rbi': 48.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d3c'), 'Player ID': 622441, 'first_name': 'Rafael', 'last_name': 'Bautista', 'team': 'Washington Nationals', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 6.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d3d'), 'Player ID': 571476, 'first_name': 'Chris', 'last_name': 'Beck', 'team': 'Memphis Redbirds', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d3e'), 'Player ID': 493596, 'first_name': 'Gordon', 'last_name': 'Beckham', 'team': 'Syracuse Mets', 'hits': 8.0, 'avg': '.182', 'homeruns': 0.0, 'atbats': 44.0, 'obp': '.250', 'stolenbases': 1.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d3f'), 'Player ID': 542921, 'first_name': 'Tim', 'last_name': 'Beckham', 'team': 'Seattle Mariners', 'hits': 85.0, 'avg': '.230', 'homeruns': 12.0, 'atbats': 369.0, 'obp': '.287', 'stolenbases': 1.0, 'rbi': 35.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d40'), 'Player ID': 592135, 'first_name': 'Cam', 'last_name': 'Bedrosian', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d41'), 'Player ID': 595881, 'first_name': 'Tyler', 'last_name': 'Beede', 'team': 'San Francisco Giants', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d42'), 'Player ID': 656222, 'first_name': 'Jalen', 'last_name': 'Beeks', 'team': 'Tampa Bay Rays', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d43'), 'Player ID': 279571, 'first_name': 'Matt', 'last_name': 'Belisle', 'team': 'Minnesota Twins', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d44'), 'Player ID': 542924, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d45'), 'Player ID': 518445, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d46'), 'Player ID': 605137, 'first_name': 'Josh', 'last_name': 'Bell', 'team': 'Pittsburgh Pirates', 'hits': 131.0, 'avg': '.261', 'homeruns': 12.0, 'atbats': 501.0, 'obp': '.357', 'stolenbases': 2.0, 'rbi': 62.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d47'), 'Player ID': 641355, 'first_name': 'Cody', 'last_name': 'Bellinger', 'team': 'Los Angeles Dodgers', 'hits': 145.0, 'avg': '.260', 'homeruns': 25.0, 'atbats': 557.0, 'obp': '.343', 'stolenbases': 14.0, 'rbi': 76.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d48'), 'Player ID': 474832, 'first_name': 'Brandon', 'last_name': 'Belt', 'team': 'San Francisco Giants', 'hits': 101.0, 'avg': '.253', 'homeruns': 14.0, 'atbats': 399.0, 'obp': '.342', 'stolenbases': 4.0, 'rbi': 46.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d49'), 'Player ID': 134181, 'first_name': 'Adrian', 'last_name': 'Beltre', 'team': 'Texas Rangers', 'hits': 118.0, 'avg': '.273', 'homeruns': 15.0, 'atbats': 433.0, 'obp': '.328', 'stolenbases': 1.0, 'rbi': 65.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d4a'), 'Player ID': 643217, 'first_name': 'Andrew', 'last_name': 'Benintendi', 'team': 'Boston Red Sox', 'hits': 168.0, 'avg': '.290', 'homeruns': 16.0, 'atbats': 579.0, 'obp': '.366', 'stolenbases': 21.0, 'rbi': 87.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d4b'), 'Player ID': 548357, 'first_name': 'Christian', 'last_name': 'Bergman', 'team': 'Tacoma Rainiers', 'hits': 1.0, 'avg': '.500', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.500', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d4c'), 'Player ID': 621244, 'first_name': 'Jose', 'last_name': 'Berrios', 'team': 'Minnesota Twins', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 4.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d4d'), 'Player ID': 542932, 'first_name': 'Jon', 'last_name': 'Berti', 'team': 'Miami Marlins', 'hits': 4.0, 'avg': '.267', 'homeruns': 0.0, 'atbats': 15.0, 'obp': '.267', 'stolenbases': 1.0, 'rbi': 2.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d4e'), 'Player ID': 476454, 'first_name': 'Dellin', 'last_name': 'Betances', 'team': 'New York Mets', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d4f'), 'Player ID': 518452, 'first_name': 'Chad', 'last_name': 'Bettis', 'team': 'Scranton/Wilkes-Barre RailRiders', 'hits': 3.0, 'avg': '.088', 'homeruns': 0.0, 'atbats': 34.0, 'obp': '.139', 'stolenbases': 0.0, 'rbi': 2.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d50'), 'Player ID': 605141, 'first_name': 'Mookie', 'last_name': 'Betts', 'team': 'Los Angeles Dodgers', 'hits': 180.0, 'avg': '.346', 'homeruns': 32.0, 'atbats': 520.0, 'obp': '.438', 'stolenbases': 30.0, 'rbi': 80.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d51'), 'Player ID': 607352, 'first_name': 'Joe', 'last_name': 'Biagini', 'team': 'Houston Astros', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d52'), 'Player ID': 502212, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d53'), 'Player ID': 592145, 'first_name': 'Jesse', 'last_name': 'Biddle', 'team': 'Cincinnati Reds', 'hits': 1.0, 'avg': '.500', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.500', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d54'), 'Player ID': 669456, 'first_name': 'Shane', 'last_name': 'Bieber', 'team': 'Cleveland Indians', 'hits': 1.0, 'avg': '.250', 'homeruns': 0.0, 'atbats': 4.0, 'obp': '.400', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d55'), 'Player ID': 595885, 'first_name': 'Greg', 'last_name': 'Bird', 'team': 'Texas Rangers', 'hits': 54.0, 'avg': '.199', 'homeruns': 11.0, 'atbats': 272.0, 'obp': '.286', 'stolenbases': 0.0, 'rbi': 38.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d56'), 'Player ID': 621389, 'first_name': 'Ty', 'last_name': 'Blach', 'team': 'Baltimore Orioles', 'hits': 1.0, 'avg': '.034', 'homeruns': 0.0, 'atbats': 29.0, 'obp': '.097', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d57'), 'Player ID': 605143, 'first_name': 'Ray', 'last_name': 'Black', 'team': 'Milwaukee Brewers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d58'), 'Player ID': 621112, 'first_name': 'Paul', 'last_name': 'Blackburn', 'team': 'Oakland Athletics', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d59'), 'Player ID': 453568, 'first_name': 'Charlie', 'last_name': 'Blackmon', 'team': 'Colorado Rockies', 'hits': 182.0, 'avg': '.291', 'homeruns': 29.0, 'atbats': 626.0, 'obp': '.358', 'stolenbases': 12.0, 'rbi': 70.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d5a'), 'Player ID': 453923, 'first_name': 'Gregor', 'last_name': 'Blanco', 'team': 'Syracuse Mets', 'hits': 41.0, 'avg': '.217', 'homeruns': 2.0, 'atbats': 189.0, 'obp': '.262', 'stolenbases': 6.0, 'rbi': 12.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d5b'), 'Player ID': 607468, 'first_name': 'Alex', 'last_name': 'Blandino', 'team': 'Cincinnati Reds', 'hits': 30.0, 'avg': '.234', 'homeruns': 1.0, 'atbats': 128.0, 'obp': '.324', 'stolenbases': 0.0, 'rbi': 8.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d5c'), 'Player ID': 518466, 'first_name': 'Jabari', 'last_name': 'Blash', 'team': 'Los Angeles Angels', 'hits': 4.0, 'avg': '.103', 'homeruns': 0.0, 'atbats': 39.0, 'obp': '.200', 'stolenbases': 2.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d5d'), 'Player ID': 542946, 'first_name': 'Jeremy', 'last_name': 'Bleich', 'team': 'Rochester Red Wings', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d5e'), 'Player ID': 542947, 'first_name': 'Richard', 'last_name': 'Bleier', 'team': 'Miami Marlins', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d5f'), 'Player ID': 460283, 'first_name': 'Jerry', 'last_name': 'Blevins', 'team': 'Sacramento River Cats', 'hits': 1.0, 'avg': '.500', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.500', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d60'), 'Player ID': 593428, 'first_name': 'Xander', 'last_name': 'Bogaerts', 'team': 'Boston Red Sox', 'hits': 148.0, 'avg': '.288', 'homeruns': 23.0, 'atbats': 513.0, 'obp': '.360', 'stolenbases': 8.0, 'rbi': 103.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d61'), 'Player ID': 593528, 'first_name': 'Jorge', 'last_name': 'Bonifacio', 'team': 'Detroit Tigers', 'hits': 53.0, 'avg': '.225', 'homeruns': 4.0, 'atbats': 236.0, 'obp': '.312', 'stolenbases': 0.0, 'rbi': 23.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d62'), 'Player ID': 621366, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d63'), 'Player ID': 607471, 'first_name': 'Christopher', 'last_name': 'Bostick', 'team': 'Norfolk Tides', 'hits': 3.0, 'avg': '.188', 'homeruns': 0.0, 'atbats': 16.0, 'obp': '.278', 'stolenbases': 0.0, 'rbi': 2.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d64'), 'Player ID': 623520, 'first_name': 'David', 'last_name': 'Bote', 'team': 'Chicago Cubs', 'hits': 44.0, 'avg': '.239', 'homeruns': 6.0, 'atbats': 184.0, 'obp': '.319', 'stolenbases': 3.0, 'rbi': 33.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d65'), 'Player ID': 571506, 'first_name': 'Justin', 'last_name': 'Bour', 'team': 'Los Angeles Angels', 'hits': 96.0, 'avg': '.227', 'homeruns': 20.0, 'atbats': 423.0, 'obp': '.341', 'stolenbases': 2.0, 'rbi': 59.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d66'), 'Player ID': 488721, 'first_name': 'Peter', 'last_name': 'Bourjos', 'team': 'Los Angeles Angels', 'hits': 9.0, 'avg': '.205', 'homeruns': 1.0, 'atbats': 44.0, 'obp': '.239', 'stolenbases': 0.0, 'rbi': 4.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d67'), 'Player ID': 621199, 'first_name': 'Matt', 'last_name': 'Bowman', 'team': 'Cincinnati Reds', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d68'), 'Player ID': 502202, 'first_name': 'Brad', 'last_name': 'Boxberger', 'team': 'Miami Marlins', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d69'), 'Player ID': 571510, 'first_name': 'Matthew', 'last_name': 'Boyd', 'team': 'Detroit Tigers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d6a'), 'Player ID': 430641, 'first_name': 'Blaine', 'last_name': 'Boyer', 'team': 'Kansas City Royals', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d6b'), 'Player ID': 542960, 'first_name': 'Brad', 'last_name': 'Brach', 'team': 'New York Mets', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d6c'), 'Player ID': 611093, 'first_name': 'Silvino', 'last_name': 'Bracho', 'team': 'Arizona Diamondbacks', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d6d'), 'Player ID': 607473, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d6e'), 'Player ID': 598265, 'first_name': 'Jackie', 'last_name': 'Bradley Jr.', 'team': 'Boston Red Sox', 'hits': 111.0, 'avg': '.234', 'homeruns': 13.0, 'atbats': 474.0, 'obp': '.314', 'stolenbases': 17.0, 'rbi': 59.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d6f'), 'Player ID': 605151, 'first_name': 'Archie', 'last_name': 'Bradley', 'team': 'Cincinnati Reds', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d70'), 'Player ID': 488726, 'first_name': 'Michael', 'last_name': 'Brantley', 'team': 'Houston Astros', 'hits': 176.0, 'avg': '.309', 'homeruns': 17.0, 'atbats': 570.0, 'obp': '.364', 'stolenbases': 12.0, 'rbi': 76.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d71'), 'Player ID': 518489, 'first_name': 'Ryan', 'last_name': 'Brasier', 'team': 'Boston Red Sox', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d72'), 'Player ID': 643230, 'first_name': 'Steven', 'last_name': 'Brault', 'team': 'Pittsburgh Pirates', 'hits': 3.0, 'avg': '.150', 'homeruns': 0.0, 'atbats': 20.0, 'obp': '.190', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d73'), 'Player ID': 460075, 'first_name': 'Ryan', 'last_name': 'Braun', 'team': 'Milwaukee Brewers', 'hits': 103.0, 'avg': '.254', 'homeruns': 20.0, 'atbats': 405.0, 'obp': '.313', 'stolenbases': 11.0, 'rbi': 64.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d74'), 'Player ID': 605154, 'first_name': 'John', 'last_name': 'Brebbia', 'team': 'St. Louis Cardinals', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d75'), 'Player ID': 608324, 'first_name': 'Alex', 'last_name': 'Bregman', 'team': 'Houston Astros', 'hits': 170.0, 'avg': '.286', 'homeruns': 31.0, 'atbats': 594.0, 'obp': '.394', 'stolenbases': 10.0, 'rbi': 103.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d76'), 'Player ID': 605155, 'first_name': 'Colten', 'last_name': 'Brewer', 'team': 'Boston Red Sox', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d77'), 'Player ID': 592169, 'first_name': 'Austin', 'last_name': 'Brice', 'team': 'Boston Red Sox', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d78'), 'Player ID': 593993, 'first_name': 'Jose', 'last_name': 'Briceno', 'team': 'Los Angeles Angels', 'hits': 28.0, 'avg': '.239', 'homeruns': 5.0, 'atbats': 117.0, 'obp': '.299', 'stolenbases': 0.0, 'rbi': 10.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d79'), 'Player ID': 592170, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d7a'), 'Player ID': 656257, 'first_name': 'Jeff', 'last_name': 'Brigham', 'team': 'Miami Marlins', 'hits': 1.0, 'avg': '.333', 'homeruns': 0.0, 'atbats': 3.0, 'obp': '.333', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d7b'), 'Player ID': 621446, 'first_name': 'Lewis', 'last_name': 'Brinson', 'team': 'Miami Marlins', 'hits': 76.0, 'avg': '.199', 'homeruns': 11.0, 'atbats': 382.0, 'obp': '.240', 'stolenbases': 2.0, 'rbi': 42.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d7c'), 'Player ID': 593647, 'first_name': 'Socrates', 'last_name': 'Brito', 'team': 'Pittsburgh Pirates', 'hits': 7.0, 'avg': '.175', 'homeruns': 1.0, 'atbats': 40.0, 'obp': '.227', 'stolenbases': 0.0, 'rbi': 3.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d7d'), 'Player ID': 502154, 'first_name': 'Zack', 'last_name': 'Britton', 'team': 'New York Yankees', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d7e'), 'Player ID': 605156, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d7f'), 'Player ID': 571521, 'first_name': 'Rex', 'last_name': 'Brothers', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d80'), 'Player ID': 542979, 'first_name': 'Keon', 'last_name': 'Broxton', 'team': 'Milwaukee Brewers', 'hits': 14.0, 'avg': '.179', 'homeruns': 4.0, 'atbats': 78.0, 'obp': '.281', 'stolenbases': 5.0, 'rbi': 11.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d81'), 'Player ID': 457803, 'first_name': 'Jay', 'last_name': 'Bruce', 'team': 'Philadelphia Phillies', 'hits': 71.0, 'avg': '.223', 'homeruns': 9.0, 'atbats': 319.0, 'obp': '.310', 'stolenbases': 2.0, 'rbi': 37.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d82'), 'Player ID': 592178, 'first_name': 'Kris', 'last_name': 'Bryant', 'team': 'Chicago Cubs', 'hits': 106.0, 'avg': '.272', 'homeruns': 13.0, 'atbats': 389.0, 'obp': '.374', 'stolenbases': 2.0, 'rbi': 52.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d83'), 'Player ID': 453329, 'first_name': 'Clay', 'last_name': 'Buchholz', 'team': 'Toronto Blue Jays', 'hits': 2.0, 'avg': '.065', 'homeruns': 0.0, 'atbats': 31.0, 'obp': '.094', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d84'), 'Player ID': 488748, 'first_name': 'Ryan', 'last_name': 'Buchter', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d85'), 'Player ID': 621111, 'first_name': 'Walker', 'last_name': 'Buehler', 'team': 'Los Angeles Dodgers', 'hits': 7.0, 'avg': '.163', 'homeruns': 0.0, 'atbats': 43.0, 'obp': '.200', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d86'), 'Player ID': 518516, 'first_name': 'Madison', 'last_name': 'Bumgarner', 'team': 'Arizona Diamondbacks', 'hits': 7.0, 'avg': '.159', 'homeruns': 0.0, 'atbats': 44.0, 'obp': '.174', 'stolenbases': 0.0, 'rbi': 4.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d87'), 'Player ID': 607481, 'first_name': 'Aaron', 'last_name': 'Bummer', 'team': 'Chicago White Sox', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d88'), 'Player ID': 605164, 'first_name': 'Dylan', 'last_name': 'Bundy', 'team': 'Los Angeles Angels', 'hits': 1.0, 'avg': '.200', 'homeruns': 0.0, 'atbats': 5.0, 'obp': '.200', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d89'), 'Player ID': 595897, 'first_name': 'Nick', 'last_name': 'Burdi', 'team': 'Pittsburgh Pirates', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d8a'), 'Player ID': 669203, 'first_name': 'Corbin', 'last_name': 'Burnes', 'team': 'Milwaukee Brewers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d8b'), 'Player ID': 621114, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d8c'), 'Player ID': 641427, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d8d'), 'Player ID': 456713, 'first_name': 'Matt', 'last_name': 'Bush', 'team': 'Texas Rangers', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d8e'), 'Player ID': 460077, 'first_name': 'Drew', 'last_name': 'Butera', 'team': 'Colorado Rockies', 'hits': 31.0, 'avg': '.190', 'homeruns': 3.0, 'atbats': 163.0, 'obp': '.264', 'stolenbases': 0.0, 'rbi': 21.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d8f'), 'Player ID': 576788, 'first_name': 'Dan', 'last_name': 'Butler', 'team': 'Boston Red Sox', 'hits': 1.0, 'avg': '.167', 'homeruns': 0.0, 'atbats': 6.0, 'obp': '.143', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d90'), 'Player ID': 572750, 'first_name': 'Eddie', 'last_name': 'Butler', 'team': 'Texas Rangers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.333', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d91'), 'Player ID': 621142, 'first_name': 'Ty', 'last_name': 'Buttrey', 'team': 'Los Angeles Angels', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d92'), 'Player ID': 621439, 'first_name': 'Byron', 'last_name': 'Buxton', 'team': 'Minnesota Twins', 'hits': 14.0, 'avg': '.156', 'homeruns': 0.0, 'atbats': 90.0, 'obp': '.183', 'stolenbases': 5.0, 'rbi': 4.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d93'), 'Player ID': 452678, 'first_name': 'Asdrubal', 'last_name': 'Cabrera', 'team': 'Washington Nationals', 'hits': 143.0, 'avg': '.262', 'homeruns': 23.0, 'atbats': 546.0, 'obp': '.316', 'stolenbases': 0.0, 'rbi': 75.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d94'), 'Player ID': 466320, 'first_name': 'Melky', 'last_name': 'Cabrera', 'team': 'Syracuse Mets', 'hits': 70.0, 'avg': '.280', 'homeruns': 6.0, 'atbats': 250.0, 'obp': '.335', 'stolenbases': 1.0, 'rbi': 39.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d95'), 'Player ID': 408234, 'first_name': 'Miguel', 'last_name': 'Cabrera', 'team': 'Detroit Tigers', 'hits': 40.0, 'avg': '.299', 'homeruns': 3.0, 'atbats': 134.0, 'obp': '.395', 'stolenbases': 0.0, 'rbi': 22.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d96'), 'Player ID': 502239, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d97'), 'Player ID': 456715, 'first_name': 'Lorenzo', 'last_name': 'Cain', 'team': 'Milwaukee Brewers', 'hits': 166.0, 'avg': '.308', 'homeruns': 10.0, 'atbats': 539.0, 'obp': '.395', 'stolenbases': 30.0, 'rbi': 38.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d98'), 'Player ID': 594777, 'first_name': 'Kole', 'last_name': 'Calhoun', 'team': 'Arizona Diamondbacks', 'hits': 102.0, 'avg': '.208', 'homeruns': 19.0, 'atbats': 491.0, 'obp': '.283', 'stolenbases': 6.0, 'rbi': 57.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d99'), 'Player ID': 641432, 'first_name': 'Willie', 'last_name': 'Calhoun', 'team': 'Texas Rangers', 'hits': 22.0, 'avg': '.222', 'homeruns': 2.0, 'atbats': 99.0, 'obp': '.269', 'stolenbases': 0.0, 'rbi': 11.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d9a'), 'Player ID': 622666, 'first_name': 'Johan', 'last_name': 'Camargo', 'team': 'Atlanta Braves', 'hits': 126.0, 'avg': '.272', 'homeruns': 19.0, 'atbats': 464.0, 'obp': '.349', 'stolenbases': 1.0, 'rbi': 76.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d9b'), 'Player ID': 600869, 'first_name': 'Jeimer', 'last_name': 'Candelario', 'team': 'Detroit Tigers', 'hits': 121.0, 'avg': '.224', 'homeruns': 19.0, 'atbats': 539.0, 'obp': '.317', 'stolenbases': 3.0, 'rbi': 54.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d9c'), 'Player ID': 592192, 'first_name': 'Mark', 'last_name': 'Canha', 'team': 'Oakland Athletics', 'hits': 91.0, 'avg': '.249', 'homeruns': 17.0, 'atbats': 365.0, 'obp': '.328', 'stolenbases': 1.0, 'rbi': 52.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d9d'), 'Player ID': 429664, 'first_name': 'Robinson', 'last_name': 'Cano', 'team': 'New York Mets', 'hits': 94.0, 'avg': '.303', 'homeruns': 10.0, 'atbats': 310.0, 'obp': '.374', 'stolenbases': 0.0, 'rbi': 50.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d9e'), 'Player ID': 605170, 'first_name': 'Victor', 'last_name': 'Caratini', 'team': 'Chicago Cubs', 'hits': 42.0, 'avg': '.232', 'homeruns': 2.0, 'atbats': 181.0, 'obp': '.293', 'stolenbases': 0.0, 'rbi': 21.0}
# {'_id': ObjectId('5f57b84a6da87065af1b3d9f'), 'Player ID': 641438, 'first_name': 'Shane', 'last_name': 'Carle', 'team': 'Texas Rangers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 4.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# ...
# {'_id': ObjectId('5f57b84a6da87065af1b4201'), 'Player ID': 621493, 'first_name': 'Taylor', 'last_name': 'Ward', 'team': 'Los Angeles Angels', 'hits': 24.0, 'avg': '.178', 'homeruns': 6.0, 'atbats': 135.0, 'obp': '.245', 'stolenbases': 2.0, 'rbi': 15.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4202'), 'Player ID': 476589, 'first_name': 'Adam', 'last_name': 'Warren', 'team': 'Trenton Thunder', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4203'), 'Player ID': 453265, 'first_name': 'Tony', 'last_name': 'Watson', 'team': 'San Francisco Giants', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4204'), 'Player ID': 596133, 'first_name': 'Luke', 'last_name': 'Weaver', 'team': 'Arizona Diamondbacks', 'hits': 6.0, 'avg': '.158', 'homeruns': 0.0, 'atbats': 38.0, 'obp': '.179', 'stolenbases': 0.0, 'rbi': 2.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4205'), 'Player ID': 643778, 'first_name': 'Tyler', 'last_name': 'Webb', 'team': 'St. Louis Cardinals', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4206'), 'Player ID': 543901, 'first_name': 'Ryan', 'last_name': 'Weber', 'team': 'Boston Red Sox', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4207'), 'Player ID': 543903, 'first_name': 'Allen', 'last_name': 'Webster', 'team': 'Harrisburg Senators', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4208'), 'Player ID': 592848, 'first_name': 'Zack', 'last_name': 'Weiss', 'team': 'Akron RubberDucks', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4209'), 'Player ID': 605525, 'first_name': 'J.B.', 'last_name': 'Wendelken', 'team': 'Oakland Athletics', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b420a'), 'Player ID': 621563, 'first_name': 'Joey', 'last_name': 'Wendle', 'team': 'Tampa Bay Rays', 'hits': 146.0, 'avg': '.300', 'homeruns': 7.0, 'atbats': 487.0, 'obp': '.354', 'stolenbases': 16.0, 'rbi': 61.0}
# {'_id': ObjectId('5f57b84a6da87065af1b420b'), 'Player ID': 547007, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b420c'), 'Player ID': 554430, 'first_name': 'Zack', 'last_name': 'Wheeler', 'team': 'Philadelphia Phillies', 'hits': 11.0, 'avg': '.196', 'homeruns': 0.0, 'atbats': 56.0, 'obp': '.193', 'stolenbases': 0.0, 'rbi': 4.0}
# {'_id': ObjectId('5f57b84a6da87065af1b420d'), 'Player ID': 643603, 'first_name': 'Tyler', 'last_name': 'White', 'team': 'Los Angeles Dodgers', 'hits': 58.0, 'avg': '.276', 'homeruns': 12.0, 'atbats': 210.0, 'obp': '.354', 'stolenbases': 0.0, 'rbi': 42.0}
# {'_id': ObjectId('5f57b84a6da87065af1b420e'), 'Player ID': 595032, 'first_name': 'Chase', 'last_name': 'Whitley', 'team': 'Atlanta Braves', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b420f'), 'Player ID': 592858, 'first_name': 'Rowan', 'last_name': 'Wick', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4210'), 'Player ID': 623364, 'first_name': 'Brad', 'last_name': 'Wieck', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4211'), 'Player ID': 446308, 'first_name': 'Matt', 'last_name': 'Wieters', 'team': 'St. Louis Cardinals', 'hits': 56.0, 'avg': '.238', 'homeruns': 8.0, 'atbats': 235.0, 'obp': '.330', 'stolenbases': 0.0, 'rbi': 30.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4212'), 'Player ID': 658792, 'first_name': 'Aaron', 'last_name': 'Wilkerson', 'team': 'Milwaukee Brewers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4213'), 'Player ID': 592859, 'first_name': 'Stevie', 'last_name': 'Wilkerson', 'team': 'Baltimore Orioles', 'hits': 8.0, 'avg': '.174', 'homeruns': 0.0, 'atbats': 46.0, 'obp': '.224', 'stolenbases': 1.0, 'rbi': 3.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4214'), 'Player ID': 657117, 'first_name': 'Austen', 'last_name': 'Williams', 'team': 'Washington Nationals', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4215'), 'Player ID': 642211, 'first_name': 'Justin', 'last_name': 'Williams', 'team': 'St. Louis Cardinals', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4216'), 'Player ID': 592863, 'first_name': 'Mason', 'last_name': 'Williams', 'team': 'Baltimore Orioles', 'hits': 36.0, 'avg': '.293', 'homeruns': 2.0, 'atbats': 123.0, 'obp': '.331', 'stolenbases': 1.0, 'rbi': 6.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4217'), 'Player ID': 608384, 'first_name': 'Nick', 'last_name': 'Williams', 'team': 'Cincinnati Reds', 'hits': 104.0, 'avg': '.256', 'homeruns': 17.0, 'atbats': 407.0, 'obp': '.324', 'stolenbases': 3.0, 'rbi': 50.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4218'), 'Player ID': 592865, 'first_name': 'Taylor', 'last_name': 'Williams', 'team': 'San Diego Padres', 'hits': 1.0, 'avg': '.250', 'homeruns': 0.0, 'atbats': 4.0, 'obp': '.250', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4219'), 'Player ID': 592866, 'first_name': 'Trevor', 'last_name': 'Williams', 'team': 'Pittsburgh Pirates', 'hits': 5.0, 'avg': '.116', 'homeruns': 0.0, 'atbats': 43.0, 'obp': '.156', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b421a'), 'Player ID': 607776, 'first_name': 'Mac', 'last_name': 'Williamson', 'team': 'Fresno Grizzlies', 'hits': 20.0, 'avg': '.213', 'homeruns': 4.0, 'atbats': 94.0, 'obp': '.295', 'stolenbases': 1.0, 'rbi': 11.0}
# {'_id': ObjectId('5f57b84a6da87065af1b421b'), 'Player ID': 543935, 'first_name': 'Alex', 'last_name': 'Wilson', 'team': 'Toledo Mud Hens', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b421c'), 'Player ID': 435064, 'first_name': 'Bobby', 'last_name': 'Wilson', 'team': 'Detroit Tigers', 'hits': 24.0, 'avg': '.178', 'homeruns': 2.0, 'atbats': 135.0, 'obp': '.242', 'stolenbases': 0.0, 'rbi': 16.0}
# {'_id': ObjectId('5f57b84a6da87065af1b421d'), 'Player ID': 669060, 'first_name': 'Bryse', 'last_name': 'Wilson', 'team': 'Atlanta Braves', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b421e'), 'Player ID': 458677, 'first_name': 'Justin', 'last_name': 'Wilson', 'team': 'New York Mets', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b421f'), 'Player ID': 622259, 'first_name': 'Trey', 'last_name': 'Wingenter', 'team': 'San Diego Padres', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4220'), 'Player ID': 608385, 'first_name': 'Jesse', 'last_name': 'Winker', 'team': 'Cincinnati Reds', 'hits': 84.0, 'avg': '.299', 'homeruns': 7.0, 'atbats': 281.0, 'obp': '.405', 'stolenbases': 0.0, 'rbi': 43.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4221'), 'Player ID': 595465, 'first_name': 'Dan', 'last_name': 'Winkler', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4222'), 'Player ID': 621550, 'first_name': 'Patrick', 'last_name': 'Wisdom', 'team': 'Chicago Cubs', 'hits': 13.0, 'avg': '.260', 'homeruns': 4.0, 'atbats': 50.0, 'obp': '.362', 'stolenbases': 2.0, 'rbi': 10.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4223'), 'Player ID': 605538, 'first_name': 'Matt', 'last_name': 'Wisler', 'team': 'Minnesota Twins', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 8.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4224'), 'Player ID': 621295, 'first_name': 'Nick', 'last_name': 'Wittgren', 'team': 'Cleveland Indians', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4225'), 'Player ID': 547172, 'first_name': 'Tony', 'last_name': 'Wolters', 'team': 'Colorado Rockies', 'hits': 31.0, 'avg': '.170', 'homeruns': 3.0, 'atbats': 182.0, 'obp': '.292', 'stolenbases': 2.0, 'rbi': 27.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4226'), 'Player ID': 543939, 'first_name': 'Kolten', 'last_name': 'Wong', 'team': 'St. Louis Cardinals', 'hits': 88.0, 'avg': '.249', 'homeruns': 9.0, 'atbats': 353.0, 'obp': '.332', 'stolenbases': 6.0, 'rbi': 38.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4227'), 'Player ID': 622072, 'first_name': 'Alex', 'last_name': 'Wood', 'team': 'Los Angeles Dodgers', 'hits': 2.0, 'avg': '.045', 'homeruns': 0.0, 'atbats': 44.0, 'obp': '.045', 'stolenbases': 1.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4228'), 'Player ID': 502028, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4229'), 'Player ID': 621056, 'first_name': 'Hunter', 'last_name': 'Wood', 'team': 'Cleveland Indians', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b422a'), 'Player ID': 605540, 'first_name': 'Brandon', 'last_name': 'Woodruff', 'team': 'Milwaukee Brewers', 'hits': 2.0, 'avg': '.250', 'homeruns': 1.0, 'atbats': 8.0, 'obp': '.333', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b422b'), 'Player ID': 519443, 'first_name': 'Brandon', 'last_name': 'Workman', 'team': 'Philadelphia Phillies', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b422c'), 'Player ID': 431151, 'first_name': 'David', 'last_name': 'Wright', 'team': 'New York Mets', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.333', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b422d'), 'Player ID': 657140, 'first_name': 'Kyle', 'last_name': 'Wright', 'team': 'Atlanta Braves', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b422e'), 'Player ID': 605541, 'first_name': 'Mike', 'last_name': 'Wright Jr.', 'team': 'Seattle Mariners', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 1.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b422f'), 'Player ID': 453214, 'first_name': 'Steven', 'last_name': 'Wright', 'team': 'Boston Red Sox', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4230'), 'Player ID': 642851, 'first_name': 'Austin', 'last_name': 'Wynns', 'team': 'Baltimore Orioles', 'hits': 28.0, 'avg': '.255', 'homeruns': 4.0, 'atbats': 110.0, 'obp': '.287', 'stolenbases': 0.0, 'rbi': 11.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4231'), 'Player ID': 642231, 'first_name': 0, 'last_name': 0, 'team': 0, 'hits': 0.0, 'avg': 0, 'homeruns': 0.0, 'atbats': 0.0, 'obp': 0, 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4232'), 'Player ID': 642232, 'first_name': 'Ryan', 'last_name': 'Yarbrough', 'team': 'Tampa Bay Rays', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 3.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4233'), 'Player ID': 489446, 'first_name': 'Kirby', 'last_name': 'Yates', 'team': 'San Diego Padres', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4234'), 'Player ID': 592885, 'first_name': 'Christian', 'last_name': 'Yelich', 'team': 'Milwaukee Brewers', 'hits': 187.0, 'avg': '.326', 'homeruns': 36.0, 'atbats': 574.0, 'obp': '.402', 'stolenbases': 22.0, 'rbi': 110.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4235'), 'Player ID': 458913, 'first_name': 'Eric', 'last_name': 'Young Jr.', 'team': 'Guerreros de Oaxaca', 'hits': 22.0, 'avg': '.202', 'homeruns': 1.0, 'atbats': 109.0, 'obp': '.248', 'stolenbases': 5.0, 'rbi': 8.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4236'), 'Player ID': 455759, 'first_name': 'Chris', 'last_name': 'Young', 'team': 'Los Angeles Angels', 'hits': 19.0, 'avg': '.168', 'homeruns': 6.0, 'atbats': 113.0, 'obp': '.252', 'stolenbases': 2.0, 'rbi': 13.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4237'), 'Player ID': 657145, 'first_name': 'Mark', 'last_name': 'Zagunis', 'team': 'Chicago Cubs', 'hits': 2.0, 'avg': '.400', 'homeruns': 0.0, 'atbats': 5.0, 'obp': '.500', 'stolenbases': 0.0, 'rbi': 1.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4238'), 'Player ID': 489448, 'first_name': 'Mike', 'last_name': 'Zagurski', 'team': 'Chicago Cubs', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4239'), 'Player ID': 623354, 'first_name': 'Daniel', 'last_name': 'Zamora', 'team': 'New York Mets', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b423a'), 'Player ID': 642239, 'first_name': 'Rob', 'last_name': 'Zastryzny', 'team': 'Baltimore Orioles', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b423b'), 'Player ID': 446899, 'first_name': 'Brad', 'last_name': 'Ziegler', 'team': 'Arizona Diamondbacks', 'hits': 0.0, 'avg': '.---', 'homeruns': 0.0, 'atbats': 0.0, 'obp': '.---', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b423c'), 'Player ID': 605548, 'first_name': 'Bradley', 'last_name': 'Zimmer', 'team': 'Cleveland Indians', 'hits': 24.0, 'avg': '.226', 'homeruns': 2.0, 'atbats': 106.0, 'obp': '.281', 'stolenbases': 4.0, 'rbi': 9.0}
# {'_id': ObjectId('5f57b84a6da87065af1b423d'), 'Player ID': 475582, 'first_name': 'Ryan', 'last_name': 'Zimmerman', 'team': 'Washington Nationals', 'hits': 76.0, 'avg': '.264', 'homeruns': 13.0, 'atbats': 288.0, 'obp': '.337', 'stolenbases': 1.0, 'rbi': 51.0}
# {'_id': ObjectId('5f57b84a6da87065af1b423e'), 'Player ID': 519455, 'first_name': 'Jordan', 'last_name': 'Zimmermann', 'team': 'Detroit Tigers', 'hits': 0.0, 'avg': '.000', 'homeruns': 0.0, 'atbats': 2.0, 'obp': '.000', 'stolenbases': 0.0, 'rbi': 0.0}
# {'_id': ObjectId('5f57b84a6da87065af1b423f'), 'Player ID': 450314, 'first_name': 'Ben', 'last_name': 'Zobrist', 'team': 'Chicago Cubs', 'hits': 139.0, 'avg': '.305', 'homeruns': 9.0, 'atbats': 455.0, 'obp': '.378', 'stolenbases': 3.0, 'rbi': 58.0}
# {'_id': ObjectId('5f57b84a6da87065af1b4240'), 'Player ID': 572287, 'first_name': 'Mike', 'last_name': 'Zunino', 'team': 'Tampa Bay Rays', 'hits': 75.0, 'avg': '.201', 'homeruns': 20.0, 'atbats': 373.0, 'obp': '.259', 'stolenbases': 0.0, 'rbi': 44.0}

# %%
scraped_stats = pd.read_csv('../cleaned_data/player_stats.csv')
scraped_stats = scraped_stats.drop(scraped_stats.columns[[0,1]], axis=1,)
scraped_stats
# Out:
#                 PLAYER   AB    R    H  HR  RBI   SO  SB  CS     BA
# 0         Mookie Betts  520  129  180  32   80   91  30   6  0.346
# 1        J.D. Martinez  569  111  188  43  130  146   6   1  0.330
# 2          Jeff McNeil  225   35   74   3   19   24   7   1  0.329
# 3     Christian Yelich  574  118  187  36  110  135  22   4  0.326
# 4          Jose Altuve  534   84  169  13   61   79  17   4  0.316
# ...                ...  ...  ...  ...  ..  ...  ...  ..  ..    ...
# 1319      Gary Sanchez  323   51   60  18   53   94   1   0  0.186
# 1320     Aaron Altherr  243   28   44   8   38   91   3   2  0.181
# 1321     Dexter Fowler  289   40   52   8   31   75   5   2  0.180
# 1322        Sandy Leon  265   30   47   5   22   75   1   0  0.177
# 1323       Chris Davis  470   40   79  16   49  192   2   0  0.168
#
# [1324 rows x 10 columns]

# %%
scraped_stats_dict = scraped_stats.to_dict('records')
# stats_dict
mongo_scraped_stats = []
mongo_scraped_stats += [scraped_stats_dict]
# mongo_stats

# %%
##L-load into mongo db--commented out for now
## cluster = MongoClient("PUT CONNECTION STRING HERE")
## db = cluster['NAME OF MLB DATABASE']
## collection = db['PUT COLLECTION NAME HERE FOR BEER']
## collection.insert_many(mongo_beer_docs)

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.mlb

db.scraped_stats.insert_many(scraped_stats_dict)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-11-f5b9f616c80b> in <module>
#       9 db = client.mlb
#      10
# ---> 11 db.scraped_stats.insert_many(scraped_stats_dict)
#
# ~\anaconda3.7\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
#     760         blk.ops = [doc for doc in gen()]
# --> 761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     763
#
# ~\anaconda3.7\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     526                 self.execute_no_results(sock_info, generator)
#     527         else:
# --> 528             return self.execute_command(generator, write_concern, session)
#     529
#     530
#
# ~\anaconda3.7\lib\site-packages\pymongo\bulk.py in execute_command(self, generator, write_concern, session)
#     361
#     362         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 363             _raise_bulk_write_error(full_result)
#     364         return full_result
#     365
#
# ~\anaconda3.7\lib\site-packages\pymongo\bulk.py in _raise_bulk_write_error(full_result)
#     138         full_result["writeErrors"].sort(
#     139             key=lambda error: error["index"])
# --> 140     raise BulkWriteError(full_result)
#     141
#     142
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('5f582c1c416d9403e847651c')}, 'errmsg': "E11000 duplicate key error collection: mlb.scraped_stats index: _id_ dup key: { _id: ObjectId('5f582c1c416d9403e847651c') }", 'op': {'PLAYER': 'Mookie Betts', 'AB': 520, 'R': 129, 'H': 180, 'HR': 32, 'RBI': 80, 'SO': 91, 'SB': 30, 'CS': 6, 'BA': 0.34600000000000003, '_id': ObjectId('5f582c1c416d9403e847651c')}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}
